# %% [markdown]
# # Artificial Intelligence Class, ECE NTUA 2021-2022: Lab Project 2
#
#
#
# ---
#
# The purpose of this project is the implementation of a Movie Recommendation System based on movies' characteristics and movie reviews. The Project is in Greek. The movies_metadata.csv, train_raitings.csv, test_raitings.csv datasets that we were provided with by our instructors at ECE NTUA are also attached. The movies_metadata.csv contains movie characteristics such as name, genre, director, actors, keywords etc, provided by IMDB. The raiting csvs contain real user movie reviews that are split in train and test datasets. Queries are written in Prolog.
#
# Quick Summary in English
# ---
# Part 1:
# Task 1a: We create the Knowledge Base.
# Task 1b: We create rules using Prolog.
#
# Part 2:
# We create the queries using Prolog.
#
# Part 3:
# We train the recommender system.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Part 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Task 1a
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Task 1b
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Part 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###Part 3: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')

import os
path="/gdrive/My Drive/" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /gdrive

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Part 1: Metadata, Environment Initialization and basic queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
import json
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}


for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  plot_keywords = clean_text(getattr(row, 'plot_keywords'))
  director_name = clean_text(getattr(row, 'director_name'))
  actor_1_name = clean_text(getattr(row, 'actor_1_name'))
  actor_2_name = clean_text(getattr(row, 'actor_2_name'))
  actor_3_name = clean_text(getattr(row, 'actor_3_name'))
  languages = clean_text(getattr(row, 'language'))
  production_comp = clean_text(getattr(row, 'production_companies'))
  production_countries = clean_text(getattr(row, 'production_countries'))
  title_year = clean_text(str(getattr(row, 'title_year')))
  genre = clean_text(str(getattr(row, 'genres')))
  ######################## OUR ADDITION - START #################
  rating = clean_text(str(getattr(row, 'vote_average')))
  voted = clean_text(str(getattr(row, 'num_voted_users')))
  duration = clean_text(str(getattr(row, 'duration')))
  ######################## OUR ADDITION - END ###################

  #Από την εκφώνηση του ερωτήματος (1β) ψάχνουμε ονόματα ταινιών, άρα αναζητούμε δεδομένα για
  #γραμμές όπου το όνομα της ταινίας είναι γνωστό.
  if (movie_title!="UNK"):

    if genre != "UNK":
      for g in genre.split("|"):
        literals.append("genre('"+ movie_title +"','"+ g +"')")



    if director_name != "UNK":
      literals.append("director('"+ movie_title +"','" + director_name + "')")



    if plot_keywords != "UNK":
      for kw in plot_keywords.split("|"):
        literals.append("keyword('" + movie_title + "','" + kw + "')")
        if (kw=="black and white"):
          color = "black and white"
        else:
          color = "colored"
      literals.append("color('" + movie_title + "','" + color + "')")



    if actor_1_name != "UNK":
      literals.append("actor('"+ movie_title +"','"+ actor_1_name +"')")

    if actor_2_name != "UNK":
      literals.append("actor('"+ movie_title +"','"+ actor_2_name +"')")

    if actor_3_name != "UNK":
      literals.append("actor('"+ movie_title +"','"+ actor_3_name +"')")



    if languages != "UNK":
      literals.append("language('"+ movie_title +"','"+ languages +"')")



    if(production_comp != "UNK"):
      x = production_comp.replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace("'", "").split(",")
      #cnt=production_comp.count(", {")+1 #how many studios ?
      for i in x:
        i=i.replace(' name: ', '')
        i=i.replace('name: ', '')
        i=i.replace(' id:' , '#') #trick to turn numbers from ' ABCD' to 'ABCD'
        i=i.replace('# ' , '')
        i=i.replace("'" , '')
        if (i.isnumeric()==False):
          name = i.split(",")[0]
          literals.append("studio-name('" + movie_title + "','" + name + "')")
        if (i.isnumeric()==True):
          id = i.split(",")[0]
          literals.append("studio-id('" + movie_title + "','" + id + "')")



    if(production_countries != "UNK"):
      y = production_countries.replace("[", "").replace("]", "").replace("{", "").replace("}", "").replace("'", "").split(",")
      #cnt=production_countries.count(", {")+1 #how many countries ?
      for i in y:
        i=i.replace('iso_3166_1', '')
        i=i.replace('name', '')
        if (i.isupper()==True):
          i=i.replace(': ', '#')
          i=i.replace('#' , '')
          iso_id = i.split(",")[0]
          literals.append("production-country-iso_3166_1('" + movie_title + "','" + iso_id + "')")
        if (i.isupper()==False):
          i=i.replace(': ', '#')
          i=i.replace(' #' , '')
          name = i.split(",")[0]
          literals.append("production-country-name('" + movie_title + "','" + name + "')")



    if title_year != "UNK":
      z=float(title_year)
      a=int(z)%10
      dec=int(z-a+10)
      dec=str(dec)
      decade=dec+'s'
      literals.append("decade('" + movie_title + "','" + decade + "')")

####################### OUR ADDITION -> Rating x Votes x Category ##############################

    if voted != "UNK":
      v=int(voted)
      if v < 51:
        voted=str(voted)
        literals.append("voted('" + movie_title + "','" + "1-50" + "')")

      elif ((v < 201) and (v > 50)):
        voted=str(voted)
        literals.append("voted('" + movie_title + "','" + "51-200" + "')")

      elif (v < 1001) and (v > 200):
        voted=str(voted)
        literals.append("voted('" + movie_title + "','" + "201-1000" + "')")

      elif v > 1000:
        voted=str(voted)
        literals.append("voted('" + movie_title + "','" + "1000+" + "')")



    if rating != "UNK":
      r=float(rating)
      if r <= 3.0:
        rating=str(rating)
        literals.append("rating('" + movie_title + "','" + "trash" + "')")

      elif (r > 3.0) and (r<=5.0):
        rating=str(rating)
        literals.append("rating('" + movie_title + "','" + "bad" + "')")

      elif (r > 5.0) and (r<=7.0):
        rating=str(rating)
        literals.append("rating('" + movie_title + "','" + "average" + "')")

      elif (r > 7.0) and (r<=8.5):
        rating=str(rating)
        literals.append("rating('" + movie_title + "','" + "good" + "')")

      elif (r > 8.5) and (r<=10.0):
        rating=str(rating)
        literals.append("rating('" + movie_title + "','" + "very good" + "')")



    if duration != "UNK":
      d=float(duration)
      if d <= 60.0:
        duration=str(duration)
        literals.append("duration('" + movie_title + "','" + "short" + "')")

      elif (d > 60.0) and (d <=120.0):
        duration=str(duration)
        literals.append("duration('" + movie_title + "','" + "normal" + "')")

      elif (d > 120.0):
        duration=str(duration)
        literals.append("duration('" + movie_title + "','" + "long" + "')")



################################### OUR ADDITION -> END #########################################

#Η Prolog θέλει τα κατηγορήματά της με την σειρά
literals.sort()
for literal in literals:
  prolog.assertz(literal)
  #print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db.pl")

# %%
# #-------------------------------------- 01 --------------------------------------#
prolog.assertz('(commongenre4(X, Y) :- genre(X, A), genre(Y, A), genre(X, B), genre(Y, B), genre(X, C), genre(Y, C), genre(X, D), genre(Y, D), A\=B, A\=C, A\=D, B\=C, B\=D, D\=C, X\=Y)') 

# #-------------------------------------- 02 --------------------------------------#
prolog.assertz('(commongenre3(X, Y) :- genre(X, A), genre(Y, A), genre(X, B), genre(Y, B), genre(X, C), genre(Y, C), A\=B, A\=C, B\=C, X\=Y, not(commongenre4(X,Y)) )') 

# #-------------------------------------- 03 --------------------------------------#
prolog.assertz('(commongenre1(X, Y) :- genre(X, A), genre(Y,A), X\=Y, not(commongenre3(X, Y)))') 

# #-------------------------------------- 04 --------------------------------------#
prolog.assertz('(commondirector(X, Y) :- director_name(X, A), director_name(Y, A), X\=Y)') 

# #-------------------------------------- 05 --------------------------------------#
prolog.assertz('(commonplot3(X, Y) :- keyword(X, A), keyword(Y, A), keyword(X, B), keyword(Y, B), keyword(X, C), keyword(Y, C), A\=B, A\=C, B\=C, X\=Y)') 

# #-------------------------------------- 06 --------------------------------------#
prolog.assertz('(commonplot2(X, Y) :- keyword(X, A), keyword(Y, A), keyword(X, B), keyword(Y, B), A\=B, X\=Y, not(commonplot3(X,Y)) )') 

# # #-------------------------------------- 07 --------------------------------------#
prolog.assertz('(commonactors3(X, Y) :- actor(X, A), actor(Y, A), actor(X, B), actor(Y, B), actor(X, C), actor(Y, C), A\=B, A\=C, B\=C, X\=Y)') 

# # #-------------------------------------- 08 --------------------------------------#
prolog.assertz('(commonactors2(X, Y) :-  actor(X,A), actor(X,B), actor(Y,A), actor(Y,B), X\=Y, A \= B, not(commonactors3(X, Y)) )')  

# # #-------------------------------------- 09 --------------------------------------#
prolog.assertz('(commonactor1(X, Y) :-  actor(X,A), actor(Y,A), X\=Y, not(commonactors2(X, Y)) )')  

# #-------------------------------------- 10 --------------------------------------#
prolog.assertz('(commonlanguage(X, Y) :- language(X, A), language(Y, A), X\=Y)')              

# #-------------------------------------- 11 --------------------------------------#
prolog.assertz('(commoncolor(X, Y) :- color(X, A), color(Y, A), X\=Y)')                       

# #-------------------------------------- 12 --------------------------------------#
prolog.assertz('(common_production_company(X, Y) :-  studio-id(X,A), studio-id(Y,A), X\=Y)')  

# #-------------------------------------- 13 --------------------------------------#
prolog.assertz('(common_production_country(X, Y) :-  production-country-iso_3166_1(X,A), production-country-iso_3166_1(Y,A), X\=Y)')    

# #-------------------------------------- 14 --------------------------------------#
prolog.assertz('(common_decade(X, Y) :-  decade(X,A), decade(Y,A), X\=Y)') 

# ####################### OUR ADDITION -> START #################################################

# # -------------------------------------- 15 --------------------------------------#
# # # movies which ratings have similar number of votes
prolog.assertz('(common_votes(X, Y) :-  voted(X, A), voted(Y, A), X\=Y)')

# # -------------------------------------- 16 --------------------------------------#
# # # movies which have common ratings
prolog.assertz('(common_rating(X, Y) :-  rating(X, A), rating(Y, A), X\=Y)')

# # -------------------------------------- 17 --------------------------------------#
# # # movies which have common duration
prolog.assertz('(common_duration(X, Y) :-  duration(X, A), duration(Y, A), X\=Y)')

################################### OUR ADDITION -> END #########################################



# q = prolog.query("common_duration('The Dark Knight Rises', M)")
# for i in q:
#   print(i["M"])

# %% [markdown]
# # **Part 2: Recommendation System based on movie characteristics.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
prolog.assertz('(find_sim_5(X, Y) :- commongenre4(X, Y); commongenre1(X, Y), commonplot3(X, Y), commonlanguage(X, Y); commongenre3(X, Y), commonactor1(X, Y), commonlanguage(X, Y), commoncolor(X, Y), not(find_sim_4(X, Y)))')
prolog.assertz('(find_sim_4(X, Y) :- commongenre4(X, Y), commonplot2(X, Y); commongenre3(X, Y), commoncolor(X, Y), common_production_company(X, Y), not(find_sim_3(X, Y)))') 
prolog.assertz('(find_sim_3(X, Y) :- commongenre1(X, Y), commonplot3(X, Y), commoncolor(X, Y); commongenre3(X, Y), commonactor1(X, Y), not(find_sim_2(X, Y)))') 
prolog.assertz('(find_sim_2(X, Y) :- commongenre3(X, Y), commonlanguage(X, Y); commonplot2(X, Y), commonlanguage(X, Y), not(find_sim_1(X, Y)))') 
prolog.assertz('(find_sim_1(X, Y) :- commongenre1(X, Y); commonplot2(X, Y))')

# %%
def simple_recommender(movie):
  def create_each_set(q):
    s = set()
    for soln in q:
      m = soln['Y'] 
      if m not in s:
        s.add(soln['Y'])
    return s

  nothing = []
  s = set()
  query = prolog.query("find_sim_5('" + movie +"',Y)")
  s = create_each_set(query)
  if(s):
    return s
  else:
    query = prolog.query("find_sim_4('" + movie +"',Y)")
    s = create_each_set(query)
    if(s):
      return s
    else:
      query = prolog.query("find_sim_3('" + movie +"',Y)")
      s = create_each_set(query)
      if(s):
        return s
      else:
        query = prolog.query("find_sim_2('" + movie +"',Y)")
        s = create_each_set(query)
        if(s):
          return s
        else:
          query = prolog.query("find_sim_1('" + movie +"',Y)")
          s = create_each_set(query)
          if(s):
            return s
          else:
            return nothing

# %%
list(simple_recommender('Avatar'))#[:20]
# Out:
# ['Jupiter Ascending',
#  'Sheena',
#  'Galaxina',
#  'Spawn',
#  'Aliens',
#  'The Shadow',
#  'The Wolverine',
#  'Superman II',
#  'Mystery Men',
#  'X-Men: Days of Future Past',
#  'Teenage Mutant Ninja Turtles III',
#  'Race to Witch Mountain',
#  'Guardians of the Galaxy',
#  'Thunderbirds',
#  'Man of Steel',
#  'Final Fantasy: The Spirits Within',
#  'Star Trek Into Darkness',
#  'Suicide Squad',
#  'Beastmaster 2: Through the Portal of Time',
#  'Underworld: Rise of the Lycans',
#  'Superman III',
#  'Teenage Mutant Ninja Turtles',
#  'Dragonball Evolution',
#  'Superman',
#  'Blade: Trinity',
#  'Superman Returns',
#  'Small Soldiers',
#  'Batman',
#  'The Fifth Element',
#  'Star Wars: Clone Wars: Volume 1',
#  'Alien³',
#  'The Covenant',
#  'Jimmy Neutron: Boy Genius']

# %% [markdown]
# # **Part 3: Recommendation System based on user reviews - Train and prediction**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')
        print("rating:",rating,", movie:",movie)

        similar_movies = simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[0]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[0] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
# for i in range (10):
#     movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
#     print(movie_score)
#     real, pred = predict_example(test_ratings, movie_score)
#     print (get_metrics(real, pred))

metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    print(movie_score)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# rating: 3.0 , movie: Spellbound
# rating: 3.5 , movie: Titanic
# rating: 1.5 , movie: The Butterfly Effect
# rating: 0.5 , movie: Live and Let Die
# rating: 4.0 , movie: Barry Lyndon
# rating: 3.5 , movie: License to Wed
# rating: 3.0 , movie: Wag the Dog
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 3.0 , movie: Flashdance
# rating: 3.5 , movie: In Time
# {'Broken Horses': 0.0, 'Eraser': 0.0, '#Horror': 0.0, 'Salton Sea': 0.0, 'The Curse of Downers Grove': 0.0, 'Shutter Island': 0.0, 'Harper': 0.0, 'Kiss the Girls': 0.0, 'Mystic River': 0.0, 'Goddess of Love': 0.0, 'Amnesiac': 0.0, 'The Dead Girl': 0.0, 'Ask Me Anything': 0.0, 'Spider': 0.0, 'The Skeleton Key': 0.0, 'Instinct': 0.0, 'Arlington Road': 0.0, '10th & Wolf': 0.0, 'Yesterday Was a Lie': 0.0, 'All Good Things': 0.0, 'Birth': 0.0, 'The Pelican Brief': 0.0, 'The Life Before Her Eyes': 0.0, 'Courage Under Fire': 0.0, 'The Girl with the Dragon Tattoo': 0.0, 'Congo': 0.0, 'The Devils Advocate': 0.0, 'The Betrayed': 0.0, 'Gossip': 0.0, 'Lies in Plain Sight': 0.0, 'The Limey': 0.0, 'Joy Ride': 0.0, 'Chloe': 0.0, 'The Generals Daughter': 0.0, 'The Bone Collector': 0.0, 'Zodiac': 0.0, 'The Bourne Ultimatum': 0.0, 'Pi': 0.0, 'Hostage': 0.0, 'Lucky Number Slevin': 0.0, 'Wonderland': 0.0, 'The Prestige': 0.0, 'The Jacket': 0.0, 'The Missing Person': 0.0, 'Boogeyman': 0.0, 'Trance': 0.0, 'The Fan': 0.0, 'Conspiracy Theory': 0.0, 'The Village': 0.0, 'Disturbia': 0.0, 'L.A. Confidential': 0.0, 'The Manchurian Candidate': 0.0, 'Knowing': 0.0, 'Blood Work': 0.0, 'Vanilla Sky': 0.0, 'The Red Violin': 0.0, 'The Order': 0.0, 'The Sisterhood of Night': 0.0, 'The Bourne Identity': 0.0, 'The Midnight Meat Train': 0.0, 'xXx: State of the Union': 0.0, 'Midnight in the Garden of Good and Evil': 0.0, 'Red Riding: In the Year of Our Lord 1974': 0.0, 'My Soul to Take': 0.0, 'Where the Truth Lies': 0.0, 'Basic': 0.0, 'Transcendence': 0.0, 'Jindabyne': 0.0, 'Ghost': 0.0, 'Deterrence': 0.0, 'Gosford Park': 0.0, 'Run All Night': 0.0, 'What Lies Beneath': 0.0, 'Topaz': 0.0, 'Double Jeopardy': 0.0, 'Young Sherlock Holmes': 0.0, 'Slow Burn': 0.0, 'Gone Girl': 0.0, 'The Spanish Prisoner': 0.0, 'The Firm': 0.0, 'Disclosure': 0.0, 'High Crimes': 0.0, 'The X Files: I Want to Believe': 0.0, 'Wicker Park': 0.0, 'Kill the Messenger': 0.0, 'Edge of Darkness': 0.0, 'The Curious Case of Benjamin Button': 0.0, 'November': 0.0, 'Smillas Sense of Snow': 0.0, 'The Pledge': 0.0, 'The Number 23': 0.0, 'Dream House': 0.0, 'Lady in the Water': 0.0, 'Frenzy': 0.0, 'Premonition': 0.0, 'The Cavemans Valentine': 0.0, 'A Walk Among the Tombstones': 0.0, 'The Net': 0.0, 'The Good German': 0.5, 'Blow Out': 0.0, 'The Negotiator': 0.0, 'Eye of the Beholder': 0.0, 'After.Life': 0.0, 'In the Valley of Elah': 0.0, 'The Client': 0.0, 'Buried': 0.0, 'Brigham City': 0.0, 'Signs': 0.0, 'Original Sin': 0.0, 'Shooter': 0.0, 'Pompeii': 0.5, 'All Superheroes Must Die': -0.5, 'Tinker Tailor Soldier Spy': 0.0, 'Clear and Present Danger': 0.0, 'May': 0.0, 'Space Cowboys': -0.5, 'Buffalo Soldiers': 0.0, 'Attack the Block': 0.0, 'The Fourth Kind': -0.5, 'Friday the 13th Part III': -0.5, 'Halloween III: Season of the Witch': -0.5, 'Man of Steel': -0.5, 'Assault on Precinct 13': -0.5, 'Fled': 0.0, 'The Woman in Black': 0.0, 'The I Inside': -0.5, 'Limbo': 0.0, 'Hitman': 0.0, 'Smokin Aces': 0.0, 'The Mist': -0.5, 'The Three Musketeers': -0.5, 'Pain & Gain': -0.5, 'A Woman, a Gun and a Noodle Shop': 0.0, 'The Adjustment Bureau': -0.5, 'The Amityville Horror': 0.0, 'Nothing': 0.0, 'Misconduct': 0.0, 'K-PAX': 0.0, 'Lights Out': -0.5, 'Megaforce': -0.5, 'Hollow Man': -0.5, 'Escape from L.A.': -0.5, 'Bicentennial Man': 0.0, 'Back to the Future Part II': 0.0, 'Spotlight': 0.0, 'The Night Listener': 0.0, 'Harry Brown': 0.0, 'Star Trek Beyond': -0.5, 'Timber Falls': -0.5, 'Zero Effect': 0.0, 'The Untouchables': 0.0, 'Romeo Is Bleeding': 0.0, 'Frailty': 0.0, 'The Score': -0.5, 'Resident Evil: Afterlife': -0.5, 'Oldboy': 0.0, 'Bubba Ho-tep': 0.0, 'Panic Room': 0.0, 'Lords of London': -0.5, 'They Live': -0.5, 'Abduction': -0.5, 'Body Double': -0.5, 'Home': 0.0, 'U-571': 0.0, 'The Talented Mr. Ripley': -1.0, 'The Lords of Salem': -0.5, 'Suspect Zero': -0.5, 'Insomnia': -0.5, 'Cirque du Freak: The Vampires Assistant': -0.5, 'Subway': -0.5, 'The Pursuit of D.B. Cooper': -0.5, 'The Hit List': -0.5, 'The Vatican Ta ...
# 0it [00:00, ?it/s]
# rating: 4.5 , movie: Team America: World Police
# rating: 2.0 , movie: Payback
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 3.0 , movie: Friends with Money
# rating: 3.5 , movie: Along Came a Spider
# rating: 2.5 , movie: Maurice
# rating: 1.5 , movie: The Butterfly Effect
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 5.0 , movie: Escape from New York
# {'The Brave Little Toaster': 1.0, 'Monkeybone': 0.5, 'Crossroads': 0.5, 'Osmosis Jones': 0.5, 'Jonah: A VeggieTales Movie': 0.5, 'Big Hero 6': 0.5, 'Kung Fu Panda 3': 0.5, 'The Adventures of Rocky & Bullwinkle': 0.5, 'Journey to Saturn': 0.0, 'Legend of a Rabbit': 0.5, 'How to Train Your Dragon 2': 0.5, 'Brave': 0.5, 'Jimmy Neutron: Boy Genius': 0.0, 'Kiss of Death': -0.5, 'Takers': -0.5, 'Need for Speed': -0.5, 'The Devils Double': -0.5, 'Stolen': -0.5, 'Mercury Rising': -0.5, 'The Protector': -0.5, 'Patriot Games': -0.5, 'The Yards': -0.5, 'Faster': -0.5, 'The Baader Meinhof Complex': -0.5, 'The Way of the Gun': -0.5, 'xXx: State of the Union': -0.5, 'Harper': -0.5, 'Dark Blue': -0.5, 'Jimmy and Judy': -0.5, 'Drive': -0.5, 'Prisoners': -0.5, 'Smillas Sense of Snow': -0.5, 'The Limey': -0.5, 'Vantage Point': -0.5, 'The Death and Life of Bobby Z': -0.5, 'Death Sentence': -0.5, 'Harsh Times': -0.5, 'Point Blank': -0.5, 'Killing Zoe': -0.5, 'Street Kings': -0.5, 'Machine Gun McCain': -0.5, 'Dead Man Down': -0.5, 'Contraband': -0.5, 'The Proposition': -0.5, 'Righteous Kill': -0.5, 'In Too Deep': -0.5, 'Training Day': -0.5, 'Running Scared': -0.5, 'I Am Wrath': -0.5, 'Basic': -0.5, 'Rampage': -0.5, 'Harry Brown': -0.5, 'Double Impact': -0.5, '10th & Wolf': -0.5, 'Man on Fire': -0.5, 'The Net': -0.5, 'United 93': -0.5, 'The Fast and the Furious: Tokyo Drift': -0.5, 'Hackers': -0.5, 'The Siege': -0.5, 'The Hunted': -0.5, 'Run All Night': -0.5, '3 Days to Kill': -0.5, 'Gangster Squad': -0.5, 'Narc': -0.5, 'The Negotiator': -0.5, 'Sabotage': -0.5, 'The Dark Knight': -0.5, 'Bound by Honor': -0.5, 'A History of Violence': -0.5, 'Hitman': -0.5, 'Shinjuku Incident': -0.5, 'Armored': -0.5, 'Scarface': -0.5, 'Young Sherlock Holmes': -0.5, 'Romeo Is Bleeding': -0.5, 'Colombiana': -0.5, 'The Replacement Killers': -0.5, 'Lone Wolf McQuade': -0.5, 'Class of 1984': -0.5, 'Get Carter': -0.5, 'The Glimmer Man': -0.5, 'Sicario': -0.5, 'The Matador': -0.5, 'The Dark Knight Rises': -0.5, 'Shooter': -0.5, '2 Guns': 0.0, 'Riding in Cars with Boys': 0.5, 'Hoodwinked!': 0.5, 'Swingers': 0.5, 'Buffalo Soldiers': -0.5, 'Attack the Block': -0.5, 'Ratatouille': 0.5, 'Miss March': 0.5, 'Boat Trip': 0.5, 'Moonrise Kingdom': 0.5, 'Dinner for Schmucks': 0.5, 'Hot Tub Time Machine 2': 0.5, 'Safe Men': 0.5, 'Fled': -0.5, 'The Heat': 0.0, 'I Love You, Dont Touch Me!': 0.5, 'Smokin Aces': -0.5, 'Good Deeds': 0.5, 'Somewhere': 0.5, 'Yes Man': 0.5, 'Detention of the Dead': 0.5, 'Shall We Dance?': 0.5, 'Hits': 0.5, 'Superbad': 0.5, 'Nims Island': 0.5, 'A Woman, a Gun and a Noodle Shop': -0.5, 'Horrible Bosses 2': 0.5, 'Human Traffic': 0.5, 'Dirty Work': 0.5, 'The Amazing Catfish': 0.5, 'Religulous': 0.5, 'Nothing': 0.0, 'Blue Like Jazz': 0.5, 'Joe Somebody': 0.5, 'New in Town': 0.5, 'Bringing Down the House': 0.5, '21 Jump Street': 0.0, 'Johnny English': 0.0, 'Bicentennial Man': 0.0, 'Back to the Future Part II': 0.0, 'Love Stinks': 0.5, 'A Charlie Brown Christmas': 0.5, 'The Women': 0.5, 'This Christmas': 0.5, 'Minions': 0.5, 'Zero Effect': -0.5, 'Dr. Dolittle 2': 0.5, 'Zookeeper': 0.5, 'Deuce Bigalow: European Gigolo': 0.5, 'Woman on Top': 0.5, 'Bubba Ho-tep': -0.5, 'Kung Fu Hustle': 0.0, 'Harold & Kumar Go to White Castle': 0.5, 'It Happened One Night': 0.5, 'Two Weeks Notice': 0.5, 'Stealing Harvard': 0.0, 'Hot Pursuit': 0.0, 'Witless Protection': 0.0, 'Seed of Chucky': 0.5, 'Foolish': 0.5, 'Home': 0.0, 'Troop Beverly Hills': 0.5, 'A Lot Like Love': 0.5, 'One for the Money': 0.0, 'The Emperors New Groove': 0.5, 'I Heart Huckabees': 0.5, 'Elizabethtown': 0.5, 'PCU': 0.5, 'Alfie': 0.5, 'Ride Along 2': 0.0, 'Flywheel': 0.5, 'Dinosaur': 0, 'How to Train Your Dragon': 0, 'Lovely & Amazing': 0.5, 'American Wedding': 0.5, 'Asterix at the Olympic Games': 0.5, 'Dumb and Dumber': 0.5, 'Mr. Hollands Opus': 0.5, 'The Stewardesses': 0.5, 'Summer Catch': 0.5, 'Whale Rider': 0.5, 'My Dog Tulip': 0.5, 'Hoot': 0.5, 'Stiff Upper Lips': 0.5, 'National Lampoons Vacation': 0.5, 'Dreame ...
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: Stand by Me
# rating: 3.0 , movie: Lions for Lambs
# rating: 5.0 , movie: The Talented Mr. Ripley
# rating: 1.0 , movie: Notting Hill
# rating: 1.5 , movie: The Butterfly Effect
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 2.0 , movie: Payback
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 1.0 , movie: Rocky Balboa
# rating: 2.0 , movie: The Last Emperor
# {'Tinker Tailor Soldier Spy': 0.0, 'G.I. Jane': 0.5, '2 Guns': 0.5, 'Riding in Cars with Boys': 0.5, 'Clear and Present Danger': 0.0, 'May': 0.0, 'The Vow': 0.5, 'Wild Grass': 0.5, 'Buffalo Soldiers': 0.0, 'Ask Me Anything': 0.0, 'Ray': 0.5, 'The Skeleton Key': 0.0, 'Moonrise Kingdom': 0.5, 'The Young Messiah': 0.5, 'Tanner Hall': 0.5, 'Miracle at St. Anna': 0.5, 'Safe Men': 0.5, 'Casino': 0.5, 'The Work and the Glory II: American Zion': 0.5, 'The Woman in Black': 0.0, 'The Heat': 0.5, 'Limbo': 0.0, 'Hitman': 0.0, 'Smokin Aces': 0.0, 'Good Deeds': 0.5, 'Somewhere': 0.5, '47 Ronin': 0.5, 'Shall We Dance?': 0.5, 'Congo': 0.0, 'Hits': 0.5, 'Pain & Gain': 0.0, 'A Woman, a Gun and a Noodle Shop': 0.0, 'Human Traffic': 0.5, 'Perfume: The Story of a Murderer': 0.5, 'Eat Pray Love': 0.5, 'F.I.S.T.': 0.5, 'Julia': 0.5, 'The Amityville Horror': 0.0, 'The Amazing Catfish': 0.5, 'The Widow of Saint-Pierre': 0.5, 'Misconduct': 0.0, 'Firestorm': 0.5, 'K-PAX': 0.0, 'Blue Like Jazz': 0.5, 'Chloe': 0.0, 'The Devils Rejects': 0.5, '21 Jump Street': 0.5, 'Boys Dont Cry': 0.5, 'Mozarts Sister': 0.5, 'Mother and Child': 0.5, 'Spotlight': 0.0, 'Fiddler on the Roof': 0.5, 'The Night Listener': 0.0, 'Harry Brown': 0.0, 'The Women': 0.5, 'This Christmas': 0.5, 'Zero Effect': 0.0, 'Valley of the Wolves: Iraq': 0.5, 'The Scarlet Letter': 0.5, 'Conspiracy Theory': 0.0, 'The Untouchables': 0.0, 'Y Tu Mamá También': 0.5, 'Romeo Is Bleeding': 0.0, 'Disturbia': 0.0, 'Frailty': 0.0, 'Woman on Top': 0.5, 'The Score': 0.0, 'The Tempest': 0.5, 'Oldboy': 0.0, 'Kung Fu Hustle': 0.5, 'Coal Miners Daughter': 0.5, 'First Love, Last Rites': 0.5, 'Panic Room': 0.0, 'Flight': 0.5, 'Lords of Dogtown': 0.5, 'Stealing Harvard': 0.5, 'Lords of London': 0.0, 'Hot Pursuit': 0.5, 'Witless Protection': 0.5, 'Seed of Chucky': 0.5, 'Futuro Beach': 0.5, 'Red Riding: In the Year of Our Lord 1974': 0.0, 'Foolish': 0.5, 'United Passions': 0.5, 'Body Double': 0.0, 'Gods and Generals': 0.5, 'U-571': 0.0, 'The Talented Mr. Ripley': 0.0, 'One for the Money': 0.5, 'Elizabethtown': 0.5, 'Never Back Down': 0.5, 'Stop-Loss': 0.5, 'Suspect Zero': 0.0, 'The Longest Ride': 0.5, 'A Passage to India': 0.5, 'Albert Nobbs': 0.5, 'Fort McCoy': 0.5, 'Insomnia': 0.0, 'Waterloo': 0.5, 'Flywheel': 0.5, 'Exodus: Gods and Kings': 0.5, 'Lovely & Amazing': 0.5, 'The Pursuit of D.B. Cooper': 0.0, 'Antarctica: A Year on Ice': 0.5, 'Romeo Must Die': 0.0, 'Mr. Hollands Opus': 0.5, 'Law Abiding Citizen': 0.0, 'Summer Catch': 0.5, 'Whale Rider': 0.5, 'My Dog Tulip': 0.5, 'The Town': 0.0, 'Moby Dick': 0.5, 'Hoot': 0.5, 'The Runaways': 0.5, 'Dreamer: Inspired By a True Story': 0.5, 'Caravans': 0.5, 'Airlift': 0.0, 'Fighting Tommy Riley': 0.5, 'The Firm': 0.0, 'Under the Skin': 0.0, 'The Celebration': 0.5, 'Idlewild': 0.5, 'The Wave': 0.0, 'The Art of Getting By': 0.5, 'Donnie Darko': 0.5, 'Dogtooth': 0.5, 'Simon Birch': 0.5, 'Light Sleeper': 0.5, 'Sparkle': 0.5, 'Carriers': 0.0, 'The Curious Case of Benjamin Button': 0.0, 'Brooklyns Finest': 0.0, 'Pierrot le Fou': 0.0, 'Forrest Gump': 0.5, 'Contagion': 0.0, 'When Did You Last See Your Father?': 0.5, 'Dolphin Tale': 0.5, 'Juliet and Alfa Romeo': 0.5, 'Kinsey': 0.5, 'Atlas Shrugged Part II': 0.0, 'Safe': 0.0, 'Gravity': 0.0, 'The Libertine': 0.5, 'The Fault in Our Stars': 0.5, 'The Bad Lieutenant: Port of Call - New Orleans': 0.5, 'The Terminal': 0.5, 'The Art of War': 0.5, 'The Horse Whisperer': 0.5, 'The Taking of Pelham 1 2 3': 0.0, 'Angelas Ashes': 0.5, 'Hud': 0.5, 'Taxman': 0.0, 'Finding Forrester': 0.5, 'Doubt': 0.5, 'Cruel Intentions': 0.0, 'The Hustler': 0.5, 'I Married a Strange Person!': 0.5, 'Exotica': 0.5, 'Judgment at Nuremberg': 0.5, 'Brick Lane': 0.5, 'The Second Best Exotic Marigold Hotel': 0.5, 'Primer': 0.0, 'Eraser': 0.0, 'Max': 0.5, 'The Lovely Bones': 0.5, 'Joe': 0.5, 'Magic Mike XXL': 0.5, 'The Pet': 0.0, 'Malevolence': 0.0, 'I Love Your Work': 0.5, 'Mr. Turner': 0.5, 'Snatch': 0.0, 'Barry Munday': 0.5, 'One True Thing': 0.5, 'Dawn of the Planet ...
# 0it [00:00, ?it/s]
# rating: 2.0 , movie: Wasabi
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 4.5 , movie: Mission: Impossible
# rating: 4.0 , movie: This Is 40
# rating: 3.0 , movie: Manderlay
# rating: 4.0 , movie: Horrible Bosses
# rating: 5.0 , movie: Escape from New York
# rating: 2.0 , movie: About Schmidt
# rating: 4.0 , movie: Pandoras Box
# {'Tinker Tailor Soldier Spy': 0.5, 'G.I. Jane': 0.5, '2 Guns': 0.5, 'Riding in Cars with Boys': 1.0, 'Clear and Present Danger': 0.5, 'May': 0.5, 'Hoodwinked!': 0.5, 'Space Cowboys': 0, 'Swingers': 0.5, 'The Vow': 0.5, 'Wild Grass': 0.5, 'Buffalo Soldiers': 1.0, 'Attack the Block': 0.5, 'Ratatouille': 0.5, 'Ask Me Anything': 0.5, '300: Rise of an Empire': 0.5, 'Miss March': 0.5, 'Ray': 0.5, 'Boat Trip': 0.5, 'The Skeleton Key': 0.5, 'Moonrise Kingdom': 1.0, 'Dinner for Schmucks': 0.5, 'The Young Messiah': 0.5, 'Man of Steel': 0, 'BloodRayne': 0, 'Tanner Hall': 0.5, 'Zodiac': 1.0, 'Hot Tub Time Machine 2': 0.5, 'The Last Witch Hunter': 0, 'Miracle at St. Anna': 0.5, 'Safe Men': 0.5, 'Casino': 1.0, 'Fled': 0.5, 'The Work and the Glory II: American Zion': 0.5, 'The Woman in Black': 0.5, 'The Heat': 0.5, 'Limbo': 0.5, 'Hitman': 1.0, 'I Love You, Dont Touch Me!': 0.5, 'Smokin Aces': 0.5, 'Good Deeds': 1.0, 'Somewhere': 1.0, 'Yes Man': 0.5, '47 Ronin': 0.5, 'Detention of the Dead': 0.5, 'Shall We Dance?': 1.0, 'Congo': 0.5, 'Hits': 1.0, 'The Three Musketeers': 0, 'Superbad': 0.5, 'Nims Island': 0.5, 'Pain & Gain': 0.5, 'A Woman, a Gun and a Noodle Shop': 1.0, 'Horrible Bosses 2': 0.5, 'Human Traffic': 1.0, 'Julia': 0.5, 'F.I.S.T.': 0.5, 'Dirty Work': 0.5, 'Eat Pray Love': 0.5, 'Perfume: The Story of a Murderer': 1.0, 'The Amazing Catfish': 1.0, 'Religulous': 0.5, 'Seabiscuit': 0.5, 'The Amityville Horror': 0.5, 'The Widow of Saint-Pierre': 0.5, 'Nothing': 0.5, 'Misconduct': 0.5, 'Firestorm': 0.5, 'K-PAX': 0.5, 'Megaforce': 0, 'Blue Like Jazz': 1.0, 'Joe Somebody': 0.5, 'Hollow Man': 0, 'New in Town': 0.5, 'Chloe': 0.5, 'The Devils Rejects': 1.0, 'Bringing Down the House': 0.5, '21 Jump Street': 0.5, 'Escape from L.A.': 1, 'Johnny English': 0.5, 'Monkeybone': 0.5, 'Bicentennial Man': 0.5, 'Back to the Future Part II': 0.5, 'Boys Dont Cry': 1.0, 'Mozarts Sister': 0.5, 'Mother and Child': 0.5, 'Spotlight': 0.5, 'Fiddler on the Roof': 0.5, 'The Night Listener': 0.5, 'Harry Brown': 1.0, 'Love Stinks': 0.5, 'A Charlie Brown Christmas': 0.5, 'Star Trek Beyond': 0, 'The Women': 1.0, 'This Christmas': 1.0, 'Minions': 0.5, 'Zero Effect': 0.5, 'Valley of the Wolves: Iraq': 0.5, 'Dr. Dolittle 2': 0.5, 'Zookeeper': 0.5, 'Conspiracy Theory': 0.5, 'The Scarlet Letter': 0.5, 'The Untouchables': 1.0, 'Deuce Bigalow: European Gigolo': 0.5, '300': 0.5, 'Romeo Is Bleeding': 1.0, 'Disturbia': 0.5, 'Frailty': 1.0, 'Woman on Top': 1.0, 'The Score': 0.5, 'Y Tu Mamá También': 0.5, 'The Tempest': 0.5, 'Oldboy': 0.5, 'Resident Evil: Afterlife': 0, 'Kung Fu Hustle': 0.5, 'Bubba Ho-tep': 0.5, 'Harold & Kumar Go to White Castle': 0.5, 'It Happened One Night': 0.5, 'Two Weeks Notice': 0.5, 'Coal Miners Daughter': 0.5, 'First Love, Last Rites': 0.5, 'Flight': 0.5, 'Lords of Dogtown': 0.5, 'Panic Room': 1.0, 'The Lord of the Rings: The Two Towers': 0, 'They Live': 0, 'Abduction': 0, 'Hot Pursuit': 0.5, 'Witless Protection': 0.5, 'Seed of Chucky': 1.0, 'Futuro Beach': 0.5, 'Red Riding: In the Year of Our Lord 1974': 1.0, 'Foolish': 1.0, 'United Passions': 0.5, 'Home': 0.5, 'Troop Beverly Hills': 0.5, 'Gods and Generals': 0, 'U-571': 0.5, 'The Talented Mr. Ripley': 1.0, 'A Lot Like Love': 0.5, 'One for the Money': 0.5, 'The Emperors New Groove': 0.5, 'I Heart Huckabees': 0.5, 'D.E.B.S.': 0, 'Never Back Down': 0.5, 'Elizabethtown': 1.0, 'Alfie': 0.5, 'PCU': 0.5, 'Stop-Loss': 0.5, 'The Longest Ride': 0.5, 'A Passage to India': 0.5, 'Albert Nobbs': 0.5, 'Ride Along 2': 0.5, 'Waterloo': 0.5, 'Fort McCoy': 0, 'Cirque du Freak: The Vampires Assistant': 0, 'Subway': 0, 'Flywheel': 0.5, 'Exodus: Gods and Kings': 0.5, 'Lovely & Amazing': 1.0, 'The Hit List': 0, 'Antarctica: A Year on Ice': 0.5, 'American Wedding': 0.5, 'Romeo Must Die': 0.5, 'Asterix at the Olympic Games': 0.5, 'Dumb and Dumber': 0.5, 'Law Abiding Citizen': 1.0, 'Mr. Hollands Opus': 0.5, 'The Stewardesses': 0.5, 'Summer Catch': 1.0, 'Whale Rider': 0.5, 'My Dog Tulip': 1.0, 'The Town': 1.0, 'Moby Dick': 0.5, ' ...
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 1.0 , movie: Alexander
# rating: 2.0 , movie: About Schmidt
# rating: 5.0 , movie: Mission to Mars
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 2.5 , movie: Rosemarys Baby
# rating: 5.0 , movie: The Wedding Planner
# rating: 2.0 , movie: Being John Malkovich
# rating: 4.0 , movie: Dear Frankie
# {'Tinker Tailor Soldier Spy': 0.5, 'G.I. Jane': 0.5, 'Riding in Cars with Boys': 0.5, 'Clear and Present Danger': 0.5, 'May': 0.5, 'The Vow': 0.5, 'Wild Grass': 0.5, 'Buffalo Soldiers': 0.5, 'Ask Me Anything': 0.5, '300: Rise of an Empire': 0.5, 'Ray': 0.5, 'The Skeleton Key': 0.5, 'Moonrise Kingdom': 0.5, 'The Young Messiah': 0.5, 'Tanner Hall': 0.5, 'Miracle at St. Anna': 0.5, 'Casino': 0.5, 'The Work and the Glory II: American Zion': 0.5, 'The Woman in Black': 0.5, 'Limbo': 0.5, 'Hitman': 0.5, 'Good Deeds': 0.5, 'Somewhere': 0.5, '47 Ronin': 0.5, 'Shall We Dance?': 0.5, 'Congo': 0.5, 'Hits': 0.5, 'A Woman, a Gun and a Noodle Shop': 0.5, 'Human Traffic': 0.5, 'Julia': 0.5, 'Eat Pray Love': 0.5, 'F.I.S.T.': 0.5, 'Perfume: The Story of a Murderer': 0.5, 'The Amityville Horror': 0.5, 'The Amazing Catfish': 0.5, 'The Widow of Saint-Pierre': 0.5, 'Misconduct': 0.5, 'K-PAX': 0.5, 'Blue Like Jazz': 0.5, 'Chloe': 0.5, 'The Devils Rejects': 0.5, 'Boys Dont Cry': 0.5, 'Mozarts Sister': 0.5, 'Mother and Child': 0.5, 'Spotlight': 0.5, 'Fiddler on the Roof': 0.5, 'The Night Listener': 0.5, 'Harry Brown': 0.5, 'The Women': 0.5, 'This Christmas': 0.5, 'Valley of the Wolves: Iraq': 0.5, 'The Scarlet Letter': 0.5, 'Conspiracy Theory': 0.5, 'The Untouchables': 0.5, 'Y Tu Mamá También': 0.5, 'Romeo Is Bleeding': 0.5, 'Disturbia': 0.5, '300': 0.5, 'Frailty': 0.5, 'Woman on Top': 0.5, 'The Tempest': 0.5, 'Oldboy': 0.5, 'Coal Miners Daughter': 0.5, 'First Love, Last Rites': 0.5, 'Flight': 0.5, 'Lords of Dogtown': 0.5, 'Panic Room': 0.5, 'Stealing Harvard': 0.5, 'Seed of Chucky': 0.5, 'Futuro Beach': 0.5, 'Red Riding: In the Year of Our Lord 1974': 0.5, 'Foolish': 0.5, 'United Passions': 0.5, 'U-571': 0.5, 'The Talented Mr. Ripley': 0.5, 'Elizabethtown': 0.5, 'Never Back Down': 0.5, 'Stop-Loss': 0.5, 'The Longest Ride': 0.5, 'A Passage to India': 0.5, 'Albert Nobbs': 0.5, 'Waterloo': 0.5, 'Flywheel': 0.5, 'Exodus: Gods and Kings': 0.5, 'Lovely & Amazing': 0.5, 'Antarctica: A Year on Ice': 0.5, 'Mr. Hollands Opus': 0.5, 'Law Abiding Citizen': 0.5, 'Summer Catch': 0.5, 'Whale Rider': 0.5, 'My Dog Tulip': 0.5, 'The Town': 0.5, 'Moby Dick': 0.5, 'Hoot': 0.5, 'The Runaways': 0.5, 'Dreamer: Inspired By a True Story': 0.5, 'Caravans': 0.0, 'Airlift': 0.5, 'Fighting Tommy Riley': 0.5, 'The Firm': 0.5, 'Under the Skin': 0.5, 'The Celebration': 0.5, 'Idlewild': 0.5, 'The Wave': 0.5, 'The Art of Getting By': 0.5, 'Donnie Darko': 0.5, 'Dogtooth': 0.5, 'Simon Birch': 0.5, 'Light Sleeper': 0.5, 'Sparkle': 0.5, 'Carriers': 0.5, 'The Curious Case of Benjamin Button': 0.5, 'Brooklyns Finest': 0.5, 'Pierrot le Fou': 0.5, 'Forrest Gump': 0.5, 'Contagion': 0.5, 'When Did You Last See Your Father?': 0.5, 'Dolphin Tale': 0.5, 'Juliet and Alfa Romeo': 0.5, 'Kinsey': 0.5, 'Atlas Shrugged Part II': 0.5, 'Gravity': 0.5, 'The Libertine': 0.5, 'The Fault in Our Stars': 0.5, 'The Bad Lieutenant: Port of Call - New Orleans': 0.5, 'The Terminal': 0.5, 'The Horse Whisperer': 0.5, 'The Taking of Pelham 1 2 3': 0.5, 'Angelas Ashes': 0.5, 'Hud': 0.5, 'Finding Forrester': 0.5, 'Doubt': 0.5, 'Cruel Intentions': 0.5, 'The Hustler': 0.5, 'I Married a Strange Person!': 0.5, 'Exotica': 0.5, 'Judgment at Nuremberg': 0.5, 'Brick Lane': 0.5, 'The Second Best Exotic Marigold Hotel': 0.5, 'Primer': 0.5, 'Black Hawk Down': 0.5, 'Eraser': 0.5, 'Max': 0.5, 'The Lovely Bones': 0.5, 'Joe': 0.5, 'Magic Mike XXL': 0.5, 'The Pet': 0.5, 'I Love Your Work': 0.5, 'Mr. Turner': 0.5, 'Barry Munday': 0.5, 'One True Thing': 0.5, 'Dawn of the Planet of the Apes': 0.5, 'An Education': 0.5, 'Filly Brown': 0.5, 'Dragon Blade': 0.5, 'Arlington Road': 0.5, 'Brothers': 0.5, 'Rampage': 0.5, 'Once Upon a Time in America': 0.5, 'Love & Basketball': 0.5, 'Oliver Twist': 0.5, 'Highway': 0.0, 'The Chambermaid on the Titanic': 0.5, 'Alexanders Ragtime Band': 0.5, 'Not Easily Broken': 0.5, 'Raging Bull': 0.5, 'The Betrayed': 0.5, 'Clay Pigeons': 0.5, 'Rush': 0.5, 'Gossip': 0.5, 'Cry Freedom': 0.5, 'Samsara': 0.5, 'Ladder  ...
# 0it [00:00, ?it/s]
# rating: 3.0 , movie: Army of Darkness
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 5.0 , movie: Space Jam
# rating: 1.0 , movie: Notting Hill
# rating: 4.0 , movie: Interview with the Vampire
# rating: 4.0 , movie: Rambo III
# rating: 2.0 , movie: About Schmidt
# rating: 1.0 , movie: Alexander
# {'Hotel Transylvania': 2, 'Black Knight': 1, 'Hotel Transylvania 2': 1, 'Southland Tales': 0, 'The Warriors Way': 1, 'A Sound of Thunder': 1, 'Serenity': 1, 'Firefox': 1, 'RoboCop 3': 1, 'The Island': 1, 'Terminator Genisys': 1, 'Spawn': 1, 'Kick-Ass 2': 0, 'Mad Max 2: The Road Warrior': 1, 'G.I. Joe: The Rise of Cobra': 1, 'The Shadow': 1, 'X2': 1, 'The Host': 0.5, 'Escape from L.A.': 1, 'The Day After Tomorrow': 1, 'Repo Men': 1, 'The Core': 1, 'The Proposition': 1, 'I Am Number Four': 1, 'X-Men: The Last Stand': 1, 'Race to Witch Mountain': 1, 'Sky Captain and the World of Tomorrow': 1, 'Star Trek II: The Wrath of Khan': 1, 'Final Fantasy: The Spirits Within': 1, 'Predator': 1, 'Star Trek V: The Final Frontier': 1, 'G.I. Joe: Retaliation': 1, '9': 1, 'Mad Max': 1, 'The Abyss': 1, 'Deadpool': 1, 'Jurassic World': 1, 'The Matrix Revolutions': 1, 'Underworld: Rise of the Lycans': 1, 'Battleship': 1, 'Babylon A.D.': 1, 'Thor: The Dark World': 0, 'Inception': 1, 'The Matrix Reloaded': 1, 'Anacondas: The Hunt for the Blood Orchid': 1, 'Armageddon': 1, 'Dragonball Evolution': 1, 'Jurassic Park III': 1, 'Moonraker': 1, 'Starship Troopers': 1, 'Blade: Trinity': 1, 'Street Fighter: The Legend of Chun-Li': 1, 'X-Men: Apocalypse': 0, 'Star Trek: Nemesis': 1, 'John Carter': 0, 'The Saint': 1, 'Star Trek: First Contact': 1, 'Mad Max: Fury Road': 1, 'Green Lantern': 1, 'Congo': 1, 'Star Trek VI: The Undiscovered Country': 1, 'Predators': 1, 'Star Trek: Generations': 1, 'Knowing': 1, 'The Fifth Element': 1, 'Star Trek: Insurrection': 1, 'Thor': 0, 'Star Trek III: The Search for Spock': 1, 'Slither': 1, 'The Covenant': 1, 'Paycheck': 1, 'Planet of the Apes': 1, 'Saints and Soldiers': 1.5, 'Tae Guk Gi: The Brotherhood of War': 1.5, 'The Charge of the Light Brigade': 1.5, 'Kingdom of Heaven': 1.5, 'Tora! Tora! Tora!': 1.5, 'Red Tails': 1.5, 'Flyboys': 1.5, 'The Messenger: The Story of Joan of Arc': 1.5, 'Das Boot': 1.5, 'The Last of the Mohicans': 1.5, 'March or Die': 1.5, 'Green Zone': 2.0, '1911': 1.5, 'Alexander': 2, 'All Superheroes Must Die': 1, 'Tinker Tailor Soldier Spy': 1, 'G.I. Jane': 1, '2 Guns': 1, 'Riding in Cars with Boys': 1, 'Clear and Present Danger': 1, 'May': 1, 'Hoodwinked!': 1, 'Swingers': 1, 'The Vow': 1, 'Space Cowboys': 1, 'Wild Grass': 1, 'Attack the Block': 1, 'Ratatouille': 2, 'The Fourth Kind': 1, 'Ask Me Anything': 1, 'Miss March': 1, 'Ray': 1, 'Boat Trip': 1, 'The Skeleton Key': 1, 'Friday the 13th Part III': 1, 'Moonrise Kingdom': 1, 'Dinner for Schmucks': 1, 'The Young Messiah': 1, 'Tanner Hall': 1, 'Zodiac': 1, 'Hot Tub Time Machine 2': 1, 'Assault on Precinct 13': 1, 'Miracle at St. Anna': 1, 'Safe Men': 1, 'Casino': 1, 'Fled': 1, 'The Work and the Glory II: American Zion': 1, 'The Woman in Black': 1, 'The Heat': 1, 'The I Inside': 1, 'Limbo': 1, 'Hitman': 1, 'I Love You, Dont Touch Me!': 1, 'Smokin Aces': 1, 'Good Deeds': 1, 'Somewhere': 1, 'Yes Man': 1, '47 Ronin': 1, 'Detention of the Dead': 1, 'Shall We Dance?': 1, 'Hits': 1, 'The Mist': 1, 'Superbad': 1, 'The Three Musketeers': 1, 'Nims Island': 1, 'Pain & Gain': 1, 'Horrible Bosses 2': 1, 'Human Traffic': 1, 'The Adjustment Bureau': 1, 'Julia': 1, 'Dirty Work': 1, 'Eat Pray Love': 1, 'F.I.S.T.': 1, 'Perfume: The Story of a Murderer': 1, 'The Amazing Catfish': 1, 'Religulous': 1, 'The Amityville Horror': 1, 'The Widow of Saint-Pierre': 1, 'Nothing': 1, 'Misconduct': 1, 'K-PAX': 1, 'Lights Out': 1, 'Blue Like Jazz': 1, 'Joe Somebody': 1, 'Hollow Man': 1, 'New in Town': 1, 'Chloe': 1, 'The Devils Rejects': 1, 'Bringing Down the House': 1, '21 Jump Street': 1, 'Johnny English': 1, 'Monkeybone': 1, 'Bicentennial Man': 1, 'Back to the Future Part II': 1, 'Boys Dont Cry': 1, 'Mozarts Sister': 1, 'Mother and Child': 1, 'Spotlight': 1, 'Fiddler on the Roof': 1, 'The Night Listener': 1, 'Love Stinks': 1, 'Harry Brown': 1, 'A Charlie Brown Christmas': 1, 'The Women': 1, 'This Christmas': 1, 'Timber Falls': 1, 'Minions': 1, 'Zero Effect': 1, 'Valley of the Wolves:  ...
# 0it [00:00, ?it/s]
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 2.0 , movie: Dragonslayer
# rating: 2.5 , movie: Romeo + Juliet
# rating: 1.0 , movie: 54
# rating: 2.5 , movie: Along Came Polly
# rating: 3.0 , movie: Wag the Dog
# rating: 3.5 , movie: License to Wed
# rating: 3.5 , movie: Open Season
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 4.0 , movie: Interview with the Vampire
# {'Home Fries': 0, 'Tin Cup': 0, 'Click': 0, 'Hitch': 0, 'Inherent Vice': 0, 'Crazy, Stupid, Love.': 0, 'Summer Catch': 0, 'Warcraft': 1, 'The Sorcerers Apprentice': 1, 'Tinker Tailor Soldier Spy': 0, 'G.I. Jane': 0, 'Riding in Cars with Boys': 0, 'Clear and Present Danger': 0, 'May': 0, 'The Vow': 0, 'Swingers': 0, 'Wild Grass': 0, 'Buffalo Soldiers': 0, 'Ask Me Anything': 0, 'Miss March': 0, 'Ray': 0, 'The Skeleton Key': 0, 'Moonrise Kingdom': 0, 'The Young Messiah': 0, 'Tanner Hall': 0, 'Miracle at St. Anna': 0, 'Casino': 0, 'The Work and the Glory II: American Zion': 0, 'The Woman in Black': 0, 'Limbo': 0, 'Hitman': 0, 'I Love You, Dont Touch Me!': 0, 'Good Deeds': 0, 'Somewhere': 0, '47 Ronin': 1, 'Shall We Dance?': 0, 'Congo': 0, 'Hits': 0, 'A Woman, a Gun and a Noodle Shop': 0, 'Human Traffic': 0, 'The Adjustment Bureau': 0, 'Julia': 0, 'Eat Pray Love': 0, 'F.I.S.T.': 0, 'Perfume: The Story of a Murderer': 0, 'The Amityville Horror': 0, 'The Amazing Catfish': 0, 'The Widow of Saint-Pierre': 0, 'Misconduct': 0, 'K-PAX': 0, 'Blue Like Jazz': 0, 'Chloe': 0, 'The Devils Rejects': 0, 'Boys Dont Cry': 0, 'Mozarts Sister': 0, 'Mother and Child': 0, 'Spotlight': 0, 'Fiddler on the Roof': 0, 'The Night Listener': 0, 'Harry Brown': 0, 'Love Stinks': 0, 'The Women': 0, 'This Christmas': 0, 'Valley of the Wolves: Iraq': 0, 'Dr. Dolittle 2': 0, 'The Scarlet Letter': 0, 'Conspiracy Theory': 0, 'Zookeeper': 0, 'The Untouchables': 0, 'Y Tu Mamá También': 0, 'Romeo Is Bleeding': 0, 'Disturbia': 0, 'Frailty': 0, 'Woman on Top': 0, 'The Tempest': 0, 'Oldboy': 0, 'It Happened One Night': 0, 'Coal Miners Daughter': 0, 'Two Weeks Notice': 0, 'First Love, Last Rites': 0, 'Flight': 0, 'Lords of Dogtown': 0, 'Panic Room': 0, 'Stealing Harvard': 0, 'Seed of Chucky': 0, 'Futuro Beach': 0, 'Red Riding: In the Year of Our Lord 1974': 0, 'Foolish': 0, 'United Passions': 0, 'Gods and Generals': 0, 'U-571': 0, 'The Talented Mr. Ripley': 0, 'I Heart Huckabees': 0, 'Elizabethtown': 0, 'Never Back Down': 0, 'Stop-Loss': 0, 'The Longest Ride': 0, 'A Passage to India': 0, 'Albert Nobbs': 0, 'Fort McCoy': 0, 'Waterloo': 0, 'Flywheel': 0, 'Exodus: Gods and Kings': 0, 'Lovely & Amazing': 0, 'Antarctica: A Year on Ice': 0, 'American Wedding': 0, 'Mr. Hollands Opus': 0, 'Law Abiding Citizen': 0, 'Whale Rider': 0, 'My Dog Tulip': 0, 'The Town': 0, 'Moby Dick': 0, 'Hoot': 0, 'The Runaways': 0, 'Dreamer: Inspired By a True Story': 0, 'National Lampoons Vacation': 0, 'Caravans': 0, 'Airlift': 0, 'Fighting Tommy Riley': 0, 'The Firm': 0, 'Under the Skin': 0, 'The Celebration': 0, 'Idlewild': 0, 'The Wave': 0, 'The Art of Getting By': 0, 'Saving Face': 0, 'Killers': 0, 'Donnie Darko': 0, 'Dogtooth': 0, 'Simon Birch': 0, 'Light Sleeper': 0, 'Sparkle': 0, 'Carriers': 0, 'The Curious Case of Benjamin Button': 0, 'Brooklyns Finest': 0, 'Pierrot le Fou': 0, 'Forrest Gump': 0, 'Contagion': 0, 'When Did You Last See Your Father?': 0, 'Dolphin Tale': 0, 'Juliet and Alfa Romeo': 0, 'Kinsey': 0, 'Atlas Shrugged Part II': 0, 'Gravity': 0, 'The Libertine': 0, 'The Fault in Our Stars': 0, 'The Bad Lieutenant: Port of Call - New Orleans': 0, 'The Terminal': 0, 'The Horse Whisperer': 0, 'The Taking of Pelham 1 2 3': 0, 'Angelas Ashes': 0, 'Hud': 0, 'Finding Forrester': 0, 'Doubt': 0, 'Cruel Intentions': 0, 'The Hustler': 0, 'Jersey Girl': 0, 'I Married a Strange Person!': 0, 'Exotica': 0, 'Judgment at Nuremberg': 0, 'Brick Lane': 0, 'The Second Best Exotic Marigold Hotel': 0, 'Primer': 0, 'Eraser': 0, 'Max': 0, 'The Lovely Bones': 0, 'Joe': 0, 'Magic Mike XXL': 0, 'The Pet': 0, 'I Love Your Work': 0, 'Mr. Turner': 0, 'Barry Munday': 0, 'Americas Sweethearts': 0, 'One True Thing': 0, 'Dawn of the Planet of the Apes': 0, 'An Education': 0, 'Filly Brown': 0, 'Dragon Blade': 0, 'Arlington Road': 0, 'Brothers': 0, 'Rampage': 0, 'The Flowers of War': 0, 'Once Upon a Time in America': 0, 'Love & Basketball': 0, 'Oliver Twist': 0, 'Highway': 0, 'Everyone Says I Love You': 0, 'The Chambermai ...
# 0it [00:00, ?it/s]
# rating: 2.0 , movie: The Last Emperor
# rating: 5.0 , movie: The Talented Mr. Ripley
# rating: 5.0 , movie: Escape from New York
# rating: 2.0 , movie: Dragonslayer
# rating: 1.0 , movie: 54
# rating: 4.0 , movie: Horrible Bosses
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 2.0 , movie: Wasabi
# rating: 3.0 , movie: Friends with Money
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# {'The Last Samurai': 0, 'Shortbus': 1.5, 'Basquiat': 0.5, 'Live and Let Die': 1, 'Transamerica': 1, 'Midnight in the Garden of Good and Evil': 1.5, 'The Good German': 1.5, 'Escape from L.A.': 1, 'Warcraft': 0, 'The Sorcerers Apprentice': 0.5, 'Party Monster': 0.0, 'Factory Girl': -0.5, 'The Oh in Ohio': 0.0, '2 Guns': 0.5, 'Riding in Cars with Boys': 0.5, 'Hoodwinked!': 0.5, 'Swingers': 0.5, 'Buffalo Soldiers': 0.5, 'Attack the Block': 0.5, 'Ratatouille': 0.5, 'Miss March': 0.5, 'Boat Trip': 0.5, 'Moonrise Kingdom': 0.5, 'Dinner for Schmucks': 0.5, 'Hot Tub Time Machine 2': 0.5, 'Safe Men': 0.5, 'Casino': 0.5, 'Fled': 0.5, 'The Heat': 0.5, 'Hitman': 0.5, 'I Love You, Dont Touch Me!': 0.5, 'Smokin Aces': 0.5, 'Good Deeds': 0.5, 'Somewhere': 0.5, 'Yes Man': 0.5, 'Detention of the Dead': 0.5, 'Shall We Dance?': 0.5, 'Hits': 0.5, 'Superbad': 0.5, 'Nims Island': 0.5, 'Pain & Gain': 0.5, 'A Woman, a Gun and a Noodle Shop': 0.5, 'Horrible Bosses 2': 0.5, 'Human Traffic': 0.5, 'Perfume: The Story of a Murderer': 0.5, 'Dirty Work': 0.5, 'The Amazing Catfish': 0.5, 'Religulous': 0.5, 'Nothing': 0.5, 'Firestorm': 0.5, 'Blue Like Jazz': 0.5, 'Joe Somebody': 0.5, 'New in Town': 0.5, 'The Devils Rejects': 0.5, 'Bringing Down the House': 0.5, '21 Jump Street': 0.5, 'Johnny English': 0.5, 'Monkeybone': 0.5, 'Bicentennial Man': 0.5, 'Back to the Future Part II': 0.5, 'Boys Dont Cry': 0.5, 'Love Stinks': 0.5, 'Harry Brown': 0.5, 'A Charlie Brown Christmas': 0.5, 'The Women': 0.5, 'This Christmas': 0.5, 'Minions': 0.5, 'Zero Effect': 0.5, 'Dr. Dolittle 2': 0.5, 'Zookeeper': 0.5, 'The Untouchables': 0.5, 'Deuce Bigalow: European Gigolo': 0.5, 'Romeo Is Bleeding': 0.5, 'Frailty': 0.5, 'Woman on Top': 0.5, 'The Score': 0.5, 'Bubba Ho-tep': 0.5, 'Kung Fu Hustle': 0.5, 'Harold & Kumar Go to White Castle': 0.5, 'It Happened One Night': 0.5, 'Two Weeks Notice': 0.5, 'Panic Room': 0.5, 'Stealing Harvard': 0.5, 'Lords of London': 0.5, 'Hot Pursuit': 0.5, 'Witless Protection': 0.5, 'Seed of Chucky': 0.5, 'Red Riding: In the Year of Our Lord 1974': 0.5, 'Foolish': 0.5, 'Body Double': 0.5, 'Home': 0.5, 'Troop Beverly Hills': 0.5, 'The Talented Mr. Ripley': 0.5, 'A Lot Like Love': 0.5, 'One for the Money': 0.5, 'The Emperors New Groove': 0.5, 'I Heart Huckabees': 0.5, 'Elizabethtown': 0.5, 'PCU': 0.5, 'Alfie': 0.5, 'Suspect Zero': 0.5, 'Ride Along 2': 0.5, 'Insomnia': 0.5, 'Lovely & Amazing': 0.5, 'The Pursuit of D.B. Cooper': 0.5, 'American Wedding': 0.5, 'Asterix at the Olympic Games': 0.5, 'Dumb and Dumber': 0.5, 'Romeo Must Die': 0.5, 'Law Abiding Citizen': 0.5, 'The Stewardesses': 0.5, 'Summer Catch': 0.5, 'My Dog Tulip': 0.5, 'The Town': 0.5, 'Stiff Upper Lips': 0.5, 'National Lampoons Vacation': 0.5, 'Idlewild': 0.5, 'A Hard Days Night': 0.5, 'Wreck-It Ralph': 0.5, 'Teeth': 0.5, 'Saving Face': 0.5, 'Why I Did (Not) Eat My Father': 0.5, 'Killers': 0.5, 'Simply Irresistible': 0.5, 'Simon Birch': 0.5, 'Light Sleeper': 0.5, 'Brooklyns Finest': 0.5, 'Forrest Gump': 0.5, 'You Dont Mess with the Zohan': 0.5, 'Juliet and Alfa Romeo': 0.5, 'Detention': 0.5, 'Safe': 0.5, 'Psycho Beach Party': 0.5, 'The Bad Lieutenant: Port of Call - New Orleans': 0.5, 'Happily NEver After': 0.5, 'The Terminal': 0.5, 'The Art of War': 0.5, 'The Taking of Pelham 1 2 3': 0.5, 'Blended': 0.5, 'Unaccompanied Minors': 0.5, 'Wild Wild West': 0.5, 'The Campaign': 0.5, 'Taxman': 0.5, 'Bee Movie': 0.5, 'Jersey Girl': 0.5, 'I Married a Strange Person!': 0.5, 'Crocodile Dundee II': 0.5, 'Home Alone': 0.5, 'Piranha 3D': 0.5, 'Racing Stripes': 0.5, 'The Second Best Exotic Marigold Hotel': 0.5, 'Keeping the Faith': 0.5, 'Magic Mike XXL': 0.5, 'Malevolence': 0.5, 'Mr. Beans Holiday': 0.5, 'Snatch': 0.5, 'Barry Munday': 0.5, 'School of Rock': 0.5, 'Americas Sweethearts': 0.5, 'Housebound': 0.5, 'Aliens in the Attic': 0.5, 'Shrek': 0.5, 'Jack Brooks: Monster Slayer': 0.5, 'Kill Bill: Vol. 1': 0.5, 'Men in Black 3': 0.5, 'See Spot Run': 0.5, 'Rampage': 0.5, 'Very Bad Things': 0.5, 'Osmosis Jones' ...
# 0it [00:00, ?it/s]
# rating: 2.5 , movie: Rosemarys Baby
# rating: 5.0 , movie: The First Wives Club
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 2.0 , movie: My Super Ex-Girlfriend
# rating: 5.0 , movie: Space Jam
# rating: 2.0 , movie: About Schmidt
# rating: 4.5 , movie: U-571
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 4.5 , movie: Match Point
# rating: 4.0 , movie: Rambo III
# {'Amnesiac': 0, 'My Soul to Take': 0, 'The Skeleton Key': 0, 'Rubber': 1, '#Horror': 0, 'Let Me In': 0, 'The Order': 0, 'The Curse of Downers Grove': 0, 'The Devils Advocate': 0, 'The Midnight Meat Train': 0, 'The Mothman Prophecies': 0, 'What Lies Beneath': 0, 'After.Life': 0, 'Boogeyman': 0, 'Goddess of Love': 0, '2 Guns': 1, 'Riding in Cars with Boys': 1, 'Hoodwinked!': 1, 'Swingers': 1, 'Buffalo Soldiers': 1, 'Attack the Block': 1, 'Ratatouille': 2, 'Miss March': 1, 'Boat Trip': 1, 'Moonrise Kingdom': 1, 'Dinner for Schmucks': 1, 'Hot Tub Time Machine 2': 1, 'Safe Men': 1, 'Fled': 1, 'The Heat': 1, 'I Love You, Dont Touch Me!': 1, 'Smokin Aces': 1, 'Good Deeds': 1, 'Somewhere': 1, 'Yes Man': 1, 'Detention of the Dead': 1, 'Shall We Dance?': 1, 'Hits': 1, 'Superbad': 1, 'Nims Island': 1, 'A Woman, a Gun and a Noodle Shop': 1, 'Horrible Bosses 2': 1, 'Human Traffic': 1, 'Dirty Work': 1, 'The Amazing Catfish': 1, 'Religulous': 1, 'Nothing': 1, 'Blue Like Jazz': 1, 'Joe Somebody': 1, 'New in Town': 1, 'Bringing Down the House': 1, '21 Jump Street': 1, 'Johnny English': 1, 'Monkeybone': 1, 'Bicentennial Man': 1, 'Back to the Future Part II': 1, 'Love Stinks': 1, 'A Charlie Brown Christmas': 1, 'The Women': 1, 'This Christmas': 1, 'Minions': 1, 'Zero Effect': 1, 'Dr. Dolittle 2': 1, 'Zookeeper': 1, 'Deuce Bigalow: European Gigolo': 1, 'Woman on Top': 1, 'Bubba Ho-tep': 1, 'Kung Fu Hustle': 1, 'Harold & Kumar Go to White Castle': 1, 'It Happened One Night': 1, 'Two Weeks Notice': 1, 'Stealing Harvard': 1, 'Hot Pursuit': 1, 'Witless Protection': 1, 'Seed of Chucky': 1, 'Foolish': 1, 'Home': 2, 'Troop Beverly Hills': 1, 'A Lot Like Love': 1, 'One for the Money': 1, 'The Emperors New Groove': 2, 'I Heart Huckabees': 1, 'Elizabethtown': 1, 'PCU': 1, 'Alfie': 1, 'Ride Along 2': 1, 'Lovely & Amazing': 1, 'American Wedding': 1, 'Asterix at the Olympic Games': 1, 'Dumb and Dumber': 1, 'The Stewardesses': 1, 'Summer Catch': 1, 'My Dog Tulip': 1, 'Stiff Upper Lips': 1, 'National Lampoons Vacation': 1, 'A Hard Days Night': 1, 'Wreck-It Ralph': 1, 'Teeth': 1, 'Saving Face': 1, 'Why I Did (Not) Eat My Father': 1, 'Killers': 1, 'Simply Irresistible': 1, 'Simon Birch': 1, 'Forrest Gump': 1, 'You Dont Mess with the Zohan': 1, 'Juliet and Alfa Romeo': 1, 'Detention': 1, 'Psycho Beach Party': 1, 'Happily NEver After': 2, 'The Terminal': 1, 'Blended': 1, 'Unaccompanied Minors': 1, 'Wild Wild West': 1, 'The Campaign': 1, 'Taxman': 1, 'Bee Movie': 1, 'Jersey Girl': 1, 'I Married a Strange Person!': 1, 'Crocodile Dundee II': 1, 'Home Alone': 1, 'Piranha 3D': 1, 'Racing Stripes': 1, 'The Second Best Exotic Marigold Hotel': 1, 'Keeping the Faith': 1, 'Magic Mike XXL': 1, 'Mr. Beans Holiday': 1, 'Barry Munday': 1, 'School of Rock': 1, 'Americas Sweethearts': 1, 'Housebound': 1, 'Aliens in the Attic': 1, 'Shrek': 2, 'Jack Brooks: Monster Slayer': 1, 'Men in Black 3': 1, 'See Spot Run': 1, 'Very Bad Things': 1, 'Osmosis Jones': 1, 'Love & Basketball': 1, 'Everyone Says I Love You': 1, 'Elsa & Fred': 1, 'Marmaduke': 1, 'Alvin and the Chipmunks: The Road Chip': 1, 'Mr. Nice Guy': 1, 'Men in Black II': 1, 'Clay Pigeons': 1, 'The Interview': 1, '22 Jump Street': 1, 'Shooting Fish': 1.5, 'Andersons Cross': 1, 'The Artist': 1, 'Soul Men': 1, 'Life During Wartime': 1, 'Neighbors 2: Sorority Rising': 1, 'Over the Hedge': 1, 'Johnny English Reborn': 1, 'Shrek 2': 2, 'Mystic Pizza': 1, 'Hudson Hawk': 1, 'Whatever It Takes': 1, 'Brüno': 1, 'Extreme Movie': 1, 'Return of the Living Dead 3': 1, 'Sex Tape': 1, 'Martin Lawrence Live: Runteldat': 1, 'House Party 2': 1, 'Seeking a Friend for the End of the World': 1, 'Foodfight!': 1, 'Enough Said': 1, 'High Heels and Low Lifes': 1, 'Freaky Friday': 1, 'The Truman Show': 1, 'The Brothers McMullen': 1, 'Girls Gone Dead': 1, 'Wonder Boys': 1, 'Ca$h': 1, 'Lethal Weapon 3': 1, 'Serial Mom': 1, 'The Sound and the Shadow': 1, 'The Last Dragon': 1, 'An Ideal Husband': 1, 'Jawbreaker': 1, 'Chairman of the Board': 1, 'The Devil Wear ...
# 0it [00:00, ?it/s]
# rating: 3.0 , movie: Lawrence of Arabia
# rating: 4.0 , movie: Flash Gordon
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 2.0 , movie: Payback
# rating: 3.0 , movie: Seven Samurai
# rating: 3.0 , movie: Gothika
# rating: 4.5 , movie: The Karate Kid
# rating: 1.0 , movie: Notting Hill
# rating: 2.5 , movie: Along Came Polly
# rating: 5.0 , movie: Dances with Wolves
# {'Saints and Soldiers': 0.5, 'Tae Guk Gi: The Brotherhood of War': 0.5, 'The Great Escape': 0.5, 'Kingdom of Heaven': 0.5, 'Tora! Tora! Tora!': 0.5, 'Red Tails': 0.5, 'Flyboys': 0.5, 'The Messenger: The Story of Joan of Arc': 0.5, 'Das Boot': 0.5, 'The Last of the Mohicans': 0.5, '1911': 0.5, 'Alexander': 0.5, 'All Superheroes Must Die': 0.5, 'Logans Run': 0.5, 'Enders Game': 0.5, 'The Lost Skeleton of Cadavra': 0.5, 'Terminator 3: Rise of the Machines': 0.5, 'Pacific Rim': 0.5, 'Splice': 0.5, 'Attack the Block': 0.5, 'Lockout': 0.5, 'The Fourth Kind': 0.5, 'Close Encounters of the Third Kind': 1.0, 'Halloween III: Season of the Witch': 0.5, 'Stake Land': 1.0, 'Kate & Leopold': 0.5, 'Man of Steel': 0.5, 'Star Wars': 0.5, 'Yesterday Was a Lie': 1.0, 'Mutant World': 0.5, 'CJ7': 1.0, 'The Astronaut Farmer': 1.0, 'Looper': 0.5, 'The I Inside': 0.5, 'The Giver': 1.0, 'Atlas Shrugged Part III: Who is John Galt?': 1.0, 'The Mist': 0.5, 'Congo': 1.0, 'Survival of the Dead': 0.5, 'Queen Crab': 0.5, 'Creative Control': 1.0, 'The Adjustment Bureau': 0.5, 'Face/Off': 0.5, 'Star Wars: Episode II - Attack of the Clones': 0.5, 'Nothing': 0.5, 'Automata': 0.5, 'K-PAX': 1.0, 'Invaders from Mars': 0.5, 'Megaforce': 0.5, 'Godzilla 2000': 0.5, 'Highlander: Endgame': 0.5, 'Hollow Man': 0.5, 'X2': 0.5, 'Stargate: The Ark of Truth': 0.5, 'Underworld: Evolution': 0.5, 'Escape from L.A.': 0.5, 'Bicentennial Man': 0.5, 'The Core': 0.5, 'Back to the Future Part II': 0.5, 'Warlock: The Armageddon': 0.5, 'Somewhere in Time': 1.0, 'Deep Blue Sea': 0.5, 'Guardians of the Galaxy': 0.5, 'Good Boy!': 0.5, 'Charly': 1.0, 'Beastmaster 2: Through the Portal of Time': 0.5, 'Delgo': 0.5, 'Star Trek Beyond': 0.5, 'Vessel': 0.5, 'The Adventures of Pluto Nash': 0.5, 'Conquest of the Planet of the Apes': 0.5, 'The Maze Runner': 0.5, 'Austin Powers in Goldmember': 0.5, 'The Saint': 0.5, 'Resident Evil: Afterlife': 0.5, 'The Fifth Element': 0.5, 'Project Almanac': 0.5, 'Idiocracy': 0.5, 'After Earth': 0.5, 'They Live': 0.5, 'The Andromeda Strain': 0.5, 'Home': 0.5, 'Apollo 18': 0.5, 'The Blood of Heroes': 0.5, 'Brazil': 0.5, 'Equilibrium': 0.5, 'The Inhabited Island': 0.5, 'E.T. the Extra-Terrestrial': 0.5, 'Tomorrowland': 0.5, 'Sleeper': 0.5, 'Armageddon': 0.5, 'Austin Powers: International Man of Mystery': 0.5, 'Species': 0.5, 'The Astronauts Wife': 1.0, 'Chain Reaction': 1.0, 'John Carter': 0.5, 'The Brain That Wouldnt Die': 0.5, 'Mad Max: Fury Road': 0.5, 'Star Trek VI: The Undiscovered Country': 0.5, 'Mirror Mirror': 1.0, 'Treasure Planet': 0.5, 'Aliens vs Predator: Requiem': 0.5, 'Space Battleship Yamato': 0.5, 'Under the Skin': 1.0, 'Escape from the Planet of the Apes': 0.5, 'Carriers': 1.0, 'Aliens': 0.5, 'Spawn': 0.5, 'Jekyll and Hyde ... Together Again': 0.5, 'Terminator Genisys': 0.5, 'The Shadow': 0.5, 'Contagion': 1.0, 'Earth to Echo': 0.5, 'Snowpiercer': 1.0, 'Atlas Shrugged Part II': 1.0, 'Detention': 0.5, 'Gravity': 1.0, 'Howard the Duck': 0.5, 'Star Wars: Episode III - Revenge of the Sith': 0.5, 'Resident Evil: Extinction': 0.5, 'Happily NEver After': 0.5, 'The Visitors': 0.5, 'G.I. Joe: Retaliation': 0.5, 'Underworld: Rise of the Lycans': 0.5, 'Code 46': 1.0, 'Battleship': 0.5, 'Iron Man 3': 0.5, 'Wild Wild West': 0.5, 'Interstellar': 1.0, 'The Lovers': 0.5, 'Decoys': 0.5, '28 Days Later': 0.5, 'Alien³': 0.5, 'Lost in Space': 0.5, 'Starship Troopers': 0.5, 'Monsters': 1.0, 'Star Trek III: The Search for Spock': 0.5, 'Transformers: Age of Extinction': 0.5, 'The Covenant': 0.5, 'District B13': 0.5, 'Independence Day': 0.5, 'Primer': 1.0, 'Renaissance': 0.5, 'Priest': 0.5, 'Firefox': 0.5, 'Listening': 1.0, 'Mad Max 2: The Road Warrior': 0.5, 'The Purge': 0.5, 'Red Planet': 0.5, 'Aliens in the Attic': 0.5, 'Dawn of the Planet of the Apes': 1.0, 'Akira': 0.5, 'AVP: Alien vs. Predator': 0.5, 'I Origins': 1.0, 'The Faculty': 0.5, 'Phantasm II': 0.5, 'Lucy': 0.5, 'Men in Black 3': 0.5, 'Transformers: Revenge of the Fallen': 0.5, 'Kingdom of the Spiders': 0.5, ' ...
# precision: 0.5175931913599097
# recall: 0.5
# f1: 0.4728281250937793

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    print(movie_score)
    real, pred = predict_example(test_ratings, movie_score)
    print (get_metrics(real, pred))
# Out:
# 0it [00:00, ?it/s]
# rating: 2.5 , movie: Maurice
# rating: 4.0 , movie: The Transporter
# rating: 4.0 , movie: Shine a Light
# rating: 5.0 , movie: Mission to Mars
# rating: 0.5 , movie: Live and Let Die
# rating: 3.0 , movie: Friends with Money
# rating: 4.0 , movie: Horrible Bosses
# rating: 5.0 , movie: The First Wives Club
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 4.0 , movie: Interview with the Vampire
# rating: 3.0 , movie: Kindergarten Cop
# rating: 2.5 , movie: Along Came Polly
# rating: 4.5 , movie: The Island
# rating: 2.0 , movie: The Last Emperor
# rating: 2.0 , movie: Notes on a Scandal
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 1.0 , movie: 54
# rating: 5.0 , movie: Amélie
# rating: 4.0 , movie: Rambo III
# rating: 4.5 , movie: Match Point
# rating: 2.0 , movie: Payback
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 3.5 , movie: Along Came a Spider
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 2.0 , movie: Being John Malkovich
# rating: 1.0 , movie: Alexander
# rating: 1.0 , movie: Notting Hill
# {'In & Out': 2.5, 'Mambo Italiano': 2.5, 'Saved!': 3.0, 'Assassins': 1.0, 'War': 1.0, 'The Transporter Refueled': 1.0, 'Colombiana': 1.5, '3 Days to Kill': 1.5, 'From Paris with Love': 1.0, 'Kiss of the Dragon': 1.0, 'Transporter 2': 1.0, 'Taken 2': 1.0, 'Hitman': 1.5, 'Alvin and the Chipmunks': 3.0, 'Alien³': 1, 'John Carter': 1, 'Zathura: A Space Adventure': 1, 'Crocodile Dundee II': 1.5, 'The Talented Mr. Ripley': 0.0, 'Hes Just Not That Into You': 3.0, 'The Switch': 3.0, '2 Guns': 2.5, 'Riding in Cars with Boys': 3.0, 'Hoodwinked!': 2.5, 'Swingers': 2.5, 'Buffalo Soldiers': 3.0, 'Attack the Block': 2.5, 'Ratatouille': 2.5, 'Miss March': 2.5, 'Boat Trip': 2.5, 'Moonrise Kingdom': 3.0, 'Dinner for Schmucks': 2.5, 'Hot Tub Time Machine 2': 2.5, 'Safe Men': 2.5, 'Casino': 1.0, 'Fled': 2.5, 'The Heat': 2.5, 'I Love You, Dont Touch Me!': 2.5, 'Smokin Aces': 2.5, 'Good Deeds': 3.0, 'Somewhere': 3.0, 'Yes Man': 2.5, 'Detention of the Dead': 2.5, 'Shall We Dance?': 3.0, 'Hits': 3.0, 'Superbad': 2.5, 'Nims Island': 2.5, 'Pain & Gain': 0.5, 'A Woman, a Gun and a Noodle Shop': 3.0, 'Horrible Bosses 2': 2.5, 'Human Traffic': 3.0, 'Perfume: The Story of a Murderer': 2.0, 'Dirty Work': 2.5, 'The Amazing Catfish': 3.0, 'Religulous': 2.5, 'Nothing': 2.5, 'Firestorm': 0.5, 'Blue Like Jazz': 3.0, 'Joe Somebody': 2.5, 'New in Town': 2.5, 'The Devils Rejects': 1.0, 'Bringing Down the House': 2.5, '21 Jump Street': 2.5, 'Johnny English': 2.5, 'Monkeybone': 2.5, 'Bicentennial Man': 2.5, 'Back to the Future Part II': 2.5, 'Boys Dont Cry': 1.0, 'Love Stinks': 2.5, 'Harry Brown': 1.5, 'A Charlie Brown Christmas': 2.5, 'The Women': 3.0, 'This Christmas': 3.0, 'Minions': 2.5, 'Zero Effect': 2.5, 'Dr. Dolittle 2': 2.5, 'Zookeeper': 2.5, 'The Untouchables': 1.0, 'Deuce Bigalow: European Gigolo': 2.5, 'Romeo Is Bleeding': 1.0, 'Frailty': 1.0, 'Woman on Top': 3.0, 'The Score': 0.5, 'Bubba Ho-tep': 2.5, 'Kung Fu Hustle': 2.5, 'Harold & Kumar Go to White Castle': 2.5, 'It Happened One Night': 2.5, 'Two Weeks Notice': 2.5, 'Panic Room': 1.0, 'Stealing Harvard': 3.0, 'Lords of London': 0.5, 'Hot Pursuit': 2.5, 'Witless Protection': 2.5, 'Seed of Chucky': 3.0, 'Red Riding: In the Year of Our Lord 1974': 1.0, 'Foolish': 3.0, 'Body Double': 0.5, 'Home': 2.5, 'Troop Beverly Hills': 2.5, 'A Lot Like Love': 2.5, 'One for the Money': 2.5, 'The Emperors New Groove': 2.5, 'I Heart Huckabees': 2.5, 'Elizabethtown': 3.0, 'PCU': 2.5, 'Alfie': 2.5, 'Suspect Zero': 0.5, 'Ride Along 2': 2.5, 'Insomnia': 0.5, 'Lovely & Amazing': 3.0, 'The Pursuit of D.B. Cooper': 0.5, 'American Wedding': 2.5, 'Asterix at the Olympic Games': 2.5, 'Dumb and Dumber': 2.5, 'Romeo Must Die': 0.5, 'Law Abiding Citizen': 1.0, 'The Stewardesses': 2.5, 'Summer Catch': 3.0, 'My Dog Tulip': 3.0, 'The Town': 1.0, 'Stiff Upper Lips': 2.5, 'National Lampoons Vacation': 2.5, 'Idlewild': 1.0, 'A Hard Days Night': 2.5, 'Wreck-It Ralph': 2.5, 'Teeth': 2.5, 'Saving Face': 2.5, 'Why I Did (Not) Eat My Father': 2.5, 'Killers': 2.5, 'Simply Irresistible': 2.5, 'Simon Birch': 3.0, 'Light Sleeper': 1.0, 'Brooklyns Finest': 1.0, 'Forrest Gump': 3.0, 'You Dont Mess with the Zohan': 2.5, 'Juliet and Alfa Romeo': 3.0, 'Detention': 2.5, 'Safe': 0.5, 'Psycho Beach Party': 2.5, 'The Bad Lieutenant: Port of Call - New Orleans': 1.0, 'Happily NEver After': 2.5, 'The Terminal': 3.0, 'The Art of War': 0.5, 'The Taking of Pelham 1 2 3': 1.0, 'Blended': 2.5, 'Unaccompanied Minors': 2.5, 'Wild Wild West': 2.5, 'The Campaign': 2.5, 'Taxman': 2.5, 'Bee Movie': 2.5, 'Jersey Girl': 2.5, 'I Married a Strange Person!': 3.0, 'Home Alone': 2.5, 'Piranha 3D': 2.5, 'Racing Stripes': 2.5, 'The Second Best Exotic Marigold Hotel': 3.0, 'Keeping the Faith': 2.5, 'Magic Mike XXL': 3.0, 'Malevolence': 0.5, 'Mr. Beans Holiday': 2.5, 'Snatch': 0.5, 'Barry Munday': 3.0, 'School of Rock': 2.5, 'Americas Sweethearts': 2.5, 'Housebound': 2.5, 'Aliens in the Attic': 2.5, 'Shrek': 2.5, 'Jack Brooks: Monster Slayer': 2.5, 'Kill Bill: Vol. 1': 0.5, 'Men ...
# {'precision': 0.5188679245283019, 'recall': 0.7638888888888888, 'f1': 0.6179775280898876}
# 0it [00:00, ?it/s]
# rating: 3.5 , movie: License to Wed
# rating: 3.5 , movie: Alvin and the Chipmunks
# rating: 5.0 , movie: Madagascar
# rating: 0.5 , movie: Rebecca
# rating: 3.5 , movie: Along Came a Spider
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 5.0 , movie: The Wedding Planner
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 2.5 , movie: Freddy vs. Jason
# rating: 3.5 , movie: Star Trek: Generations
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# rating: 4.0 , movie: The Kite Runner
# rating: 5.0 , movie: The First Wives Club
# rating: 0.5 , movie: Live and Let Die
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 0.5 , movie: Amadeus
# rating: 4.0 , movie: Shine a Light
# rating: 4.0 , movie: Horrible Bosses
# rating: 4.0 , movie: The French Connection
# rating: 4.0 , movie: Cinderella Man
# rating: 3.5 , movie: Open Season
# rating: 5.0 , movie: Amélie
# rating: 2.5 , movie: Romeo + Juliet
# rating: 4.0 , movie: Dear Frankie
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 4.0 , movie: The Legend of Suriyothai
# {'Four Weddings and a Funeral': 6.0, '27 Dresses': 4.0, 'The Brave Little Toaster': 4.0, 'Shine a Light': 0, 'Wreck-It Ralph': 4.0, 'The Lego Movie': 4.0, 'A Monster in Paris': 4.0, 'The Croods': 4.0, 'Ratatouille': 4.0, 'Home': 4.0, 'This Is It': 0, 'Walk Hard: The Dewey Cox Story': 4.0, 'Shrek the Third': 4.5, 'Hotel Transylvania': 4.0, 'Shrek': 4.0, 'Shrek 2': 4.0, 'The Emperors New Groove': 4.0, 'Space Jam': 5.0, 'Alvin and the Chipmunks: Chipwrecked': 4.0, 'The Ant Bully': 4.0, 'Happily NEver After': 4.0, 'Aladdin': 4.0, 'Delgo': 4.0, 'Josie and the Pussycats': 4.0, 'Alvin and the Chipmunks: The Squeakquel': 4.0, 'The Book of Life': 4.0, 'The Smurfs 2': 4.0, 'Curious George': 4.0, 'How to Train Your Dragon 2': 3.5, 'Rio': 4.0, 'Cats Dont Dance': 4.0, 'Jonah: A VeggieTales Movie': 3.5, 'Stuart Little': 4.0, 'The Smurfs': 4.0, 'Jimmy Neutron: Boy Genius': 4.0, 'Mr. Peabody & Sherman': 0, 'Shrek Forever After': 4.0, 'The Boxtrolls': 4.0, 'Brave': 3.5, 'Monster House': 4.0, 'Madagascar: Escape 2 Africa': 1, 'Heavenly Creatures': 1.5, 'Notes on a Scandal': 2.5, 'Conspiracy Theory': 1.0, 'The Postman Always Rings Twice': 3.0, 'Stir of Echoes': -0.5, 'xXx: State of the Union': 2.5, 'Harper': 2.5, 'The Limey': 2.5, 'Smillas Sense of Snow': 2.5, 'The Losers': 1.0, 'The Fugitive': 1.0, 'Copycat': 2.0, 'Basic': 2.5, 'The Net': 2.5, '10th & Wolf': 2.5, 'Nancy Drew': 1.0, 'The Corruptor': 1.0, 'Run All Night': 2.5, 'The Negotiator': 2.5, 'Alex Cross': 1.0, 'The Long Kiss Goodnight': 1.0, 'Young Sherlock Holmes': 2.5, 'Whiteout': 1.0, 'Now You See Me 2': 3.5, 'The Adventures of Ford Fairlane': 4.0, 'Disclosure': 3.5, 'Sicario': 2.5, 'Shooter': 2.5, 'The Warriors Way': 0.5, 'A Sound of Thunder': 0.5, 'Serenity': 0.5, 'Firefox': 0.5, 'RoboCop 3': 1.0, 'The Island': 0.5, 'Terminator Genisys': 0.5, 'Spawn': 1.0, 'Kick-Ass 2': 0.0, 'Mad Max 2: The Road Warrior': 0.5, 'G.I. Joe: The Rise of Cobra': 0.5, 'The Shadow': 1.0, 'X2': 0.5, 'The Host': 3.0, 'Escape from L.A.': 0.5, 'The Day After Tomorrow': 0.5, 'Repo Men': 1.0, 'The Core': 0.5, 'The Proposition': 2.5, 'Southland Tales': 3.5, 'I Am Number Four': 0.5, 'X-Men: The Last Stand': 0.5, 'Race to Witch Mountain': 1.0, 'Sky Captain and the World of Tomorrow': 0.5, 'Star Trek II: The Wrath of Khan': 0.5, 'Final Fantasy: The Spirits Within': 1.0, 'Predator': 0.5, 'Star Trek V: The Final Frontier': 0.5, 'G.I. Joe: Retaliation': 0.5, '9': 0.5, 'Mad Max': 0.5, 'The Abyss': 0.5, 'Deadpool': 3.5, 'Jurassic World': 0.5, 'The Matrix Revolutions': 0.5, 'Underworld: Rise of the Lycans': 1.0, 'Battleship': 0.5, 'Babylon A.D.': 0.5, 'Thor: The Dark World': -0.5, 'Inception': 0.5, 'The Matrix Reloaded': 0.5, 'Anacondas: The Hunt for the Blood Orchid': 0.5, 'Armageddon': 1.5, 'Dragonball Evolution': 1.0, 'Jurassic Park III': 0.5, 'Moonraker': 0.5, 'Starship Troopers': 0.5, 'Blade: Trinity': 0.5, 'Street Fighter: The Legend of Chun-Li': 0.5, 'X-Men: Apocalypse': 0, 'Star Trek: Nemesis': 0.5, 'John Carter': -0.5, 'The Saint': 1.5, 'Star Trek: First Contact': 0.5, 'Mad Max: Fury Road': 0.5, 'Green Lantern': 0.5, 'Congo': 2.0, 'Star Trek VI: The Undiscovered Country': 0.5, 'Predators': 0.5, 'Star Trek: Generations': 0.5, 'Knowing': 2.0, 'The Fifth Element': 1.0, 'Star Trek: Insurrection': 0.5, 'Thor': -0.5, 'Star Trek III: The Search for Spock': 0.5, 'Slither': 4.0, 'The Covenant': 1.0, 'Paycheck': 0.5, 'Planet of the Apes': 0.5, 'My Best Friends Wedding': 5.0, 'Indiana Jones and the Temple of Doom': -0.5, 'The Adventures of Tintin': 0, 'Lara Croft Tomb Raider: The Cradle of Life': 0.5, 'Lara Croft: Tomb Raider': 0.5, 'Indiana Jones and the Kingdom of the Crystal Skull': -0.5, 'Cabin Fever': 0, 'X-Men Origins: Wolverine': 0.5, 'The League of Extraordinary Gentlemen': 1.0, 'Jupiter Ascending': 0.0, 'Sheena': 4.0, 'Tank Girl': 4.0, 'Daybreakers': 1.0, 'Highlander: Endgame': 0.0, 'The Wolverine': 0.0, 'Dragon Wars: D-War': 2.5, 'Underworld: Evolution': 1.0, 'Mortal Kombat: Annihilation': 0.0, 'Superman II': 0.0,  ...
# {'precision': 0.5241935483870968, 'recall': 0.9027777777777778, 'f1': 0.6632653061224489}
# 0it [00:00, ?it/s]
# rating: 0.5 , movie: Amadeus
# rating: 2.0 , movie: Dragonslayer
# rating: 1.0 , movie: Notting Hill
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 4.5 , movie: Mission: Impossible
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 3.5 , movie: In Time
# rating: 5.0 , movie: Mission to Mars
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 1.0 , movie: Alexander
# rating: 4.0 , movie: Pandoras Box
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 4.0 , movie: The French Connection
# rating: 4.0 , movie: Stand by Me
# rating: 2.0 , movie: The Sixth Sense
# rating: 3.0 , movie: Gothika
# rating: 2.0 , movie: The Last Emperor
# rating: 5.0 , movie: Escape from New York
# rating: 3.0 , movie: Wag the Dog
# rating: 4.0 , movie: The Transporter
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 4.5 , movie: The Island
# rating: 2.0 , movie: Wasabi
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 3.0 , movie: Spellbound
# rating: 4.5 , movie: U-571
# rating: 2.5 , movie: Maurice
# rating: 4.0 , movie: Cinderella Man
# rating: 2.0 , movie: Payback
# {'Evita': 0.0, 'Cadillac Records': 0.0, '1776': -0.5, 'Joyeux Noël': -0.5, 'Warcraft': 0, 'The Sorcerers Apprentice': 1.0, 'Basquiat': 0.5, 'Finding Neverland': 0.5, 'Grabbers': 0.5, 'The Lost Skeleton of Cadavra': 0.5, 'Detention': 0.5, 'Repo! The Genetic Opera': 0.5, 'Slither': 0.5, 'The Toxic Avenger': 0.5, 'Dylan Dog: Dead of Night': 0.5, 'Lake Placid': 0.5, 'RED 2': 1.5, 'Get Smart': 1.0, 'Spy Kids: All the Time in the World': 1.0, 'Salt': 1.0, 'True Lies': 0.5, 'Central Intelligence': 1.0, 'Jack Ryan: Shadow Recruit': 1.5, 'Tinker Tailor Soldier Spy': 1.0, 'G.I. Jane': 1.0, '2 Guns': 1.0, 'Riding in Cars with Boys': 1.0, 'Clear and Present Danger': 1.0, 'May': 1.0, 'Hoodwinked!': 0.5, 'Swingers': 0.5, 'The Vow': 1.0, 'Wild Grass': 1.0, 'Buffalo Soldiers': 1.0, 'Attack the Block': 0.5, 'Ratatouille': 0.5, 'Ask Me Anything': 1.0, 'Miss March': 0.5, 'Ray': 1.0, 'Boat Trip': 0.5, 'The Skeleton Key': 1.0, 'Moonrise Kingdom': 1.0, 'Dinner for Schmucks': 0.5, 'The Young Messiah': 1.0, 'Tanner Hall': 1.0, 'Zodiac': 1.0, 'Hot Tub Time Machine 2': 0.5, 'Miracle at St. Anna': 1.0, 'Safe Men': 1.0, 'Casino': 1.0, 'Fled': 0.5, 'The Work and the Glory II: American Zion': 1.0, 'The Woman in Black': 1.0, 'The Heat': 1.0, 'Limbo': 1.0, 'Hitman': 2.0, 'I Love You, Dont Touch Me!': 0.5, 'Smokin Aces': 1.0, 'Good Deeds': 1.0, 'Somewhere': 1.0, 'Yes Man': 0.5, '47 Ronin': 1.0, 'Detention of the Dead': 0.5, 'Shall We Dance?': 1.0, 'Congo': 1.5, 'Hits': 1.0, 'Superbad': 0.5, 'Nims Island': 0.5, 'A Woman, a Gun and a Noodle Shop': 1.0, 'Horrible Bosses 2': 0.5, 'Human Traffic': 1.0, 'Julia': 1.0, 'Dirty Work': 0.5, 'Eat Pray Love': 1.0, 'F.I.S.T.': 1.0, 'Perfume: The Story of a Murderer': 1.0, 'The Amazing Catfish': 1.0, 'Religulous': 0.5, 'The Amityville Horror': 1.0, 'The Widow of Saint-Pierre': 1.0, 'Nothing': 0.5, 'Misconduct': 1.0, 'K-PAX': 1.0, 'Blue Like Jazz': 1.0, 'Joe Somebody': 0.5, 'New in Town': 0.5, 'Chloe': 1.0, 'The Devils Rejects': 1.0, 'Bringing Down the House': 0.5, '21 Jump Street': 1.0, 'Johnny English': 0.5, 'Monkeybone': 0.5, 'Bicentennial Man': 0.5, 'Back to the Future Part II': 0.5, 'Boys Dont Cry': 1.0, 'Mozarts Sister': 1.0, 'Mother and Child': 1.0, 'Spotlight': 1.0, 'Fiddler on the Roof': 1.0, 'The Night Listener': 1.0, 'Love Stinks': 0.5, 'Harry Brown': 1.0, 'A Charlie Brown Christmas': 0.5, 'The Women': 1.0, 'This Christmas': 1.0, 'Minions': 0.5, 'Zero Effect': 1.0, 'Valley of the Wolves: Iraq': 1.0, 'Dr. Dolittle 2': 0.5, 'Zookeeper': 0.5, 'Conspiracy Theory': 1.0, 'The Scarlet Letter': 1.0, 'The Untouchables': 1.0, 'Deuce Bigalow: European Gigolo': 0.5, 'Romeo Is Bleeding': 1.0, 'Disturbia': 1.0, 'Y Tu Mamá También': 1.0, 'Frailty': 1.0, 'Woman on Top': 1.0, 'The Tempest': 1.0, 'Oldboy': 1.0, 'Bubba Ho-tep': 0.5, 'Kung Fu Hustle': 1.0, 'Harold & Kumar Go to White Castle': 0.5, 'It Happened One Night': 0.5, 'Two Weeks Notice': 0.5, 'Coal Miners Daughter': 1.0, 'First Love, Last Rites': 1.0, 'Flight': 1.0, 'Lords of Dogtown': 1.0, 'Stealing Harvard': 1.0, 'Panic Room': 1.0, 'Hot Pursuit': 1.0, 'Witless Protection': 1.0, 'Seed of Chucky': 1.0, 'Futuro Beach': 1.0, 'Red Riding: In the Year of Our Lord 1974': 1.0, 'Foolish': 1.0, 'United Passions': 1.0, 'Home': 0.5, 'Troop Beverly Hills': 0.5, 'Gods and Generals': 1.0, 'U-571': 1.0, 'The Talented Mr. Ripley': 1.0, 'A Lot Like Love': 0.5, 'One for the Money': 1.0, 'The Emperors New Groove': 0.5, 'I Heart Huckabees': 0.5, 'Elizabethtown': 1.0, 'PCU': 0.5, 'Alfie': 0.5, 'Never Back Down': 1.0, 'Stop-Loss': 1.0, 'The Longest Ride': 1.0, 'A Passage to India': 1.0, 'Albert Nobbs': 1.0, 'Ride Along 2': 0.5, 'Fort McCoy': 1.0, 'Waterloo': 1.0, 'Flywheel': 1.0, 'Lovely & Amazing': 1.0, 'Exodus: Gods and Kings': 1.0, 'Antarctica: A Year on Ice': 1.0, 'American Wedding': 0.5, 'Asterix at the Olympic Games': 0.5, 'Dumb and Dumber': 0.5, 'Mr. Hollands Opus': 1.0, 'Law Abiding Citizen': 1.0, 'The Stewardesses': 0.5, 'Summer Catch': 1.0, 'Whale Rider': 1.0, 'My Dog Tulip': 1.0, 'The ...
# {'precision': 0.5225225225225225, 'recall': 0.8055555555555556, 'f1': 0.6338797814207651}
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: The French Connection
# rating: 3.0 , movie: Psycho
# rating: 3.5 , movie: In Time
# rating: 2.0 , movie: The Sixth Sense
# rating: 4.0 , movie: Flash Gordon
# rating: 2.5 , movie: Freddy vs. Jason
# rating: 1.0 , movie: 54
# rating: 2.0 , movie: Payback
# rating: 4.5 , movie: Mission: Impossible
# rating: 5.0 , movie: The Wedding Planner
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 3.0 , movie: Flashdance
# rating: 3.0 , movie: Manderlay
# rating: 3.5 , movie: Star Trek: Generations
# rating: 2.0 , movie: My Super Ex-Girlfriend
# rating: 4.5 , movie: U-571
# rating: 3.0 , movie: Gothika
# rating: 5.0 , movie: Solaris
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 4.0 , movie: The Transporter
# rating: 4.0 , movie: Interview with the Vampire
# rating: 3.5 , movie: Open Season
# rating: 4.0 , movie: Barry Lyndon
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 4.5 , movie: Team America: World Police
# rating: 4.0 , movie: Stand by Me
# rating: 4.5 , movie: The Karate Kid
# rating: 2.0 , movie: Notes on a Scandal
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 4.0 , movie: The Kite Runner
# {'Kiss of Death': 2.0, 'The Siege': 2.0, 'Death Sentence': 2.0, 'The Sentinel': 1.0, 'The Adventures of Ford Fairlane': 1.0, 'Kiss of the Dragon': 1.5, 'Transporter 2': 1.5, 'Taken 2': 1.5, 'Hitman': 2.5, 'The Wolfman': 1.5, 'Bless the Child': 1.5, 'The Skeleton Key': 1.5, 'Firestarter': 1.5, 'World War Z': 2.0, 'Cat People': 1.5, 'White Noise': 1.5, 'Frequency': 2.0, 'Instinct': 1.5, 'Abandon': 1.5, 'The Bourne Ultimatum': 1.5, 'All Superheroes Must Die': 0.5, 'Logans Run': 0.5, 'Enders Game': 0.5, 'The Lost Skeleton of Cadavra': 0.5, 'Terminator 3: Rise of the Machines': 0.5, 'Pacific Rim': 0.5, 'Splice': 0.5, 'Attack the Block': 0.5, 'Lockout': 0.5, 'The Fourth Kind': 0.5, 'Close Encounters of the Third Kind': 2.0, 'Halloween III: Season of the Witch': 0.5, 'Stake Land': 2.0, 'Kate & Leopold': 0.5, 'Man of Steel': 0.5, 'Star Wars': 0.5, 'Yesterday Was a Lie': 2.0, 'Mutant World': 0.5, 'CJ7': 2.0, 'The Astronaut Farmer': 2.0, 'Looper': 0.5, 'The I Inside': 0.5, 'The Giver': 2.0, 'Atlas Shrugged Part III: Who is John Galt?': 2.0, 'The Mist': 0.5, 'Congo': 3.0, 'Survival of the Dead': 0.5, 'Queen Crab': 0.5, 'Creative Control': 2.0, 'The Adjustment Bureau': 0.5, 'Face/Off': 1.0, 'Star Wars: Episode II - Attack of the Clones': 0.5, 'Nothing': 1.0, 'Automata': 0.5, 'K-PAX': 2.0, 'Invaders from Mars': 0.5, 'Megaforce': 0.5, 'Godzilla 2000': 0.5, 'Highlander: Endgame': 0.5, 'Hollow Man': 0.5, 'X2': 0.5, 'Stargate: The Ark of Truth': 0.5, 'Underworld: Evolution': 0.5, 'Escape from L.A.': 0.5, 'Bicentennial Man': 0.5, 'The Core': 0.5, 'Back to the Future Part II': 0.5, 'Warlock: The Armageddon': 0.5, 'Somewhere in Time': 2.0, 'Deep Blue Sea': 0.5, 'Guardians of the Galaxy': 0.5, 'Good Boy!': 0.5, 'Charly': 2.0, 'Beastmaster 2: Through the Portal of Time': 0.5, 'Delgo': 0.5, 'Star Trek Beyond': 0.5, 'Vessel': 0.5, 'The Adventures of Pluto Nash': 0.5, 'Conquest of the Planet of the Apes': 0.5, 'The Maze Runner': 0.5, 'Austin Powers in Goldmember': 1.0, 'The Saint': 0.5, 'Resident Evil: Afterlife': 0.5, 'The Fifth Element': 0.5, 'Project Almanac': 0.5, 'Idiocracy': 0.5, 'After Earth': 0.5, 'They Live': 0.5, 'The Andromeda Strain': 0.5, 'Home': 0.5, 'Apollo 18': 0.5, 'The Blood of Heroes': 0.5, 'Brazil': 0.5, 'Equilibrium': 0.5, 'The Inhabited Island': 0.5, 'E.T. the Extra-Terrestrial': 0.5, 'Tomorrowland': 0.5, 'Sleeper': 0.5, 'Armageddon': 0.5, 'Austin Powers: International Man of Mystery': 1.0, 'Species': 0.5, 'The Astronauts Wife': 2.0, 'Chain Reaction': 2.0, 'John Carter': 0.5, 'The Brain That Wouldnt Die': 0.5, 'Mad Max: Fury Road': 0.5, 'Star Trek VI: The Undiscovered Country': 0.5, 'Mirror Mirror': 2.0, 'Treasure Planet': 0.5, 'Aliens vs Predator: Requiem': 0.5, 'Space Battleship Yamato': 0.5, 'Under the Skin': 2.0, 'Escape from the Planet of the Apes': 0.5, 'Carriers': 2.0, 'Aliens': 0.5, 'Spawn': 0.5, 'Jekyll and Hyde ... Together Again': 0.5, 'Terminator Genisys': 0.5, 'The Shadow': 0.5, 'Contagion': 2.0, 'Earth to Echo': 0.5, 'Snowpiercer': 2.0, 'Atlas Shrugged Part II': 2.0, 'Detention': 0.5, 'Gravity': 2.0, 'Howard the Duck': 0.5, 'Star Wars: Episode III - Revenge of the Sith': 0.5, 'Resident Evil: Extinction': 0.5, 'Happily NEver After': 0.5, 'The Visitors': 0.5, 'G.I. Joe: Retaliation': 0.5, 'Underworld: Rise of the Lycans': 0.5, 'Code 46': 2.0, 'Battleship': 0.5, 'Iron Man 3': 0.5, 'Wild Wild West': 0.5, 'Interstellar': 2.0, 'The Lovers': 0.5, 'Decoys': 0.5, '28 Days Later': 0.5, 'Alien³': 0.5, 'Lost in Space': 0.5, 'Starship Troopers': 0.5, 'Monsters': 2.0, 'Star Trek III: The Search for Spock': 0.5, 'Transformers: Age of Extinction': 0.5, 'The Covenant': 0.5, 'District B13': 0.5, 'Independence Day': 0.5, 'Primer': 2.0, 'Renaissance': 0.5, 'Priest': 0.5, 'Firefox': 0.5, 'Listening': 2.0, 'Mad Max 2: The Road Warrior': 0.5, 'The Purge': 0.5, 'Red Planet': 0.5, 'Aliens in the Attic': 0.5, 'Dawn of the Planet of the Apes': 2.0, 'Akira': 0.5, 'AVP: Alien vs. Predator': 0.5, 'I Origins': 2.0, 'The Faculty': 0.5, 'Phantasm I ...
# {'precision': 0.494949494949495, 'recall': 0.6805555555555556, 'f1': 0.5730994152046783}
# 0it [00:00, ?it/s]
# rating: 4.5 , movie: The Karate Kid
# rating: 5.0 , movie: Mission to Mars
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 2.0 , movie: About Schmidt
# rating: 3.0 , movie: Kindergarten Cop
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 2.5 , movie: Freddy vs. Jason
# rating: 5.0 , movie: The Wedding Planner
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 5.0 , movie: Solaris
# rating: 3.0 , movie: Lions for Lambs
# rating: 1.0 , movie: Rocky Balboa
# rating: 4.5 , movie: Mission: Impossible
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# rating: 4.0 , movie: This Is 40
# rating: 3.0 , movie: Army of Darkness
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 3.5 , movie: Star Trek: Generations
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 4.0 , movie: Shine a Light
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 1.0 , movie: 54
# rating: 3.0 , movie: Flashdance
# rating: 0.5 , movie: Rebecca
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 3.0 , movie: Gothika
# rating: 3.0 , movie: Friends with Money
# rating: 2.0 , movie: The Last Emperor
# rating: 1.5 , movie: The Butterfly Effect
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# {'Tinker Tailor Soldier Spy': 1.5, 'G.I. Jane': 2.0, 'Riding in Cars with Boys': 2.0, 'Clear and Present Danger': 1.5, 'May': 1.5, 'The Vow': 2.0, 'Wild Grass': 2.0, 'Buffalo Soldiers': 1.0, 'Ask Me Anything': 1.5, 'Ray': 2.0, 'The Skeleton Key': 1.5, 'Moonrise Kingdom': 2.0, 'The Young Messiah': 2.0, 'Tanner Hall': 2.0, 'Miracle at St. Anna': 2.0, 'Casino': 2.0, 'The Work and the Glory II: American Zion': 2.0, 'The Woman in Black': 1.5, 'Limbo': 1.5, 'Hitman': 1.5, 'Good Deeds': 2.0, 'Somewhere': 2.0, '47 Ronin': 3.0, 'Shall We Dance?': 2.0, 'Congo': 2.5, 'Hits': 2.0, 'A Woman, a Gun and a Noodle Shop': 0.5, 'Human Traffic': 2.0, 'Julia': 2.0, 'Eat Pray Love': 2.0, 'F.I.S.T.': 2.0, 'Perfume: The Story of a Murderer': 2.0, 'The Amityville Horror': 1.5, 'The Amazing Catfish': 2.0, 'The Widow of Saint-Pierre': 2.0, 'Misconduct': 1.5, 'K-PAX': 1.5, 'Blue Like Jazz': 2.0, 'Chloe': 1.5, 'The Devils Rejects': 2.0, 'Boys Dont Cry': 2.0, 'Mozarts Sister': 2.0, 'Mother and Child': 2.0, 'Spotlight': 1.5, 'Fiddler on the Roof': 2.0, 'The Night Listener': 1.5, 'Harry Brown': 1.5, 'The Women': 2.0, 'This Christmas': 2.0, 'Valley of the Wolves: Iraq': 2.0, 'The Scarlet Letter': 2.0, 'Conspiracy Theory': 0.5, 'The Untouchables': 1.5, 'Y Tu Mamá También': 2.0, 'Romeo Is Bleeding': 1.5, 'Disturbia': 1.5, 'Frailty': 1.5, 'Woman on Top': 2.0, 'The Tempest': 2.0, 'Oldboy': 1.5, 'Coal Miners Daughter': 2.0, 'First Love, Last Rites': 2.0, 'Flight': 2.0, 'Lords of Dogtown': 2.0, 'Panic Room': 1.5, 'Stealing Harvard': 2.0, 'Seed of Chucky': 2.0, 'Futuro Beach': 2.0, 'Red Riding: In the Year of Our Lord 1974': 1.5, 'Foolish': 2.0, 'United Passions': 2.0, 'Gods and Generals': 2.0, 'U-571': 1.5, 'The Talented Mr. Ripley': 1.5, 'Elizabethtown': 2.0, 'Never Back Down': 2.0, 'Stop-Loss': 2.0, 'The Longest Ride': 2.0, 'A Passage to India': 2.0, 'Albert Nobbs': 2.0, 'Fort McCoy': 2.0, 'Waterloo': 2.0, 'Flywheel': 2.0, 'Exodus: Gods and Kings': 2.0, 'Lovely & Amazing': 2.0, 'Antarctica: A Year on Ice': 2.0, 'Mr. Hollands Opus': 2.0, 'Law Abiding Citizen': 1.5, 'Summer Catch': 2.0, 'Whale Rider': 2.0, 'My Dog Tulip': 2.0, 'The Town': 1.5, 'Moby Dick': 2.0, 'Hoot': 2.0, 'The Runaways': 2.0, 'Dreamer: Inspired By a True Story': 2.0, 'Caravans': 2.0, 'Airlift': 1.5, 'Fighting Tommy Riley': 2.0, 'The Firm': 1.5, 'Under the Skin': 1.5, 'The Celebration': 2.0, 'Idlewild': 2.0, 'The Wave': 1.5, 'The Art of Getting By': 2.0, 'Donnie Darko': 2.0, 'Dogtooth': 2.0, 'Simon Birch': 2.0, 'Light Sleeper': 2.0, 'Sparkle': 2.0, 'Carriers': 1.5, 'The Curious Case of Benjamin Button': 1.5, 'Brooklyns Finest': 1.5, 'Pierrot le Fou': 1.5, 'Forrest Gump': 2.0, 'Contagion': 1.5, 'When Did You Last See Your Father?': 2.0, 'Dolphin Tale': 2.0, 'Juliet and Alfa Romeo': 2.0, 'Kinsey': 2.0, 'Atlas Shrugged Part II': 1.5, 'Gravity': 1.5, 'The Libertine': 2.0, 'The Fault in Our Stars': 2.0, 'The Bad Lieutenant: Port of Call - New Orleans': 2.0, 'The Terminal': 2.0, 'The Horse Whisperer': 2.0, 'The Taking of Pelham 1 2 3': 1.5, 'Angelas Ashes': 2.0, 'Hud': 2.0, 'Finding Forrester': 2.0, 'Doubt': 2.0, 'Cruel Intentions': 1.5, 'The Hustler': 2.0, 'I Married a Strange Person!': 2.0, 'Exotica': 2.0, 'Judgment at Nuremberg': 2.0, 'Brick Lane': 2.0, 'The Second Best Exotic Marigold Hotel': 2.0, 'Primer': 1.5, 'Eraser': 1.5, 'Max': 2.0, 'The Lovely Bones': 2.0, 'Joe': 2.0, 'Magic Mike XXL': 2.0, 'The Pet': 1.5, 'I Love Your Work': 2.0, 'Mr. Turner': 2.0, 'Barry Munday': 2.0, 'One True Thing': 2.0, 'Dawn of the Planet of the Apes': 1.5, 'An Education': 2.0, 'Filly Brown': 2.0, 'Dragon Blade': 2.0, 'Arlington Road': 1.5, 'Brothers': 1.5, 'Rampage': 1.5, 'The Flowers of War': 2.0, 'Once Upon a Time in America': 2.0, 'Love & Basketball': 2.0, 'Oliver Twist': 2.0, 'Highway': 2.0, 'The Chambermaid on the Titanic': 2.0, 'Alexanders Ragtime Band': 2.0, 'Not Easily Broken': 2.0, 'Raging Bull': 1.5, 'The Betrayed': 1.5, 'Clay Pigeons': 1.0, 'Rush': 2.0, 'Gossip': 1.5, 'Cry Freedom': 2.0, 'Samsara': 2.0, 'La ...
# {'precision': 0.5241935483870968, 'recall': 0.9027777777777778, 'f1': 0.6632653061224489}
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: The French Connection
# rating: 4.0 , movie: Flash Gordon
# rating: 2.0 , movie: Payback
# rating: 4.0 , movie: The Transporter
# rating: 4.5 , movie: Team America: World Police
# rating: 4.0 , movie: The Kite Runner
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 3.0 , movie: Friends with Money
# rating: 3.0 , movie: Psycho
# rating: 3.5 , movie: Along Came a Spider
# rating: 2.0 , movie: The Last Emperor
# rating: 5.0 , movie: The Wedding Planner
# rating: 1.0 , movie: Notting Hill
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating: 2.5 , movie: Along Came Polly
# rating: 4.0 , movie: Barry Lyndon
# rating: 5.0 , movie: Escape from New York
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 0.5 , movie: Live and Let Die
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 0.5 , movie: Rebecca
# rating: 3.5 , movie: License to Wed
# rating: 2.0 , movie: Wasabi
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 4.0 , movie: Interview with the Vampire
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 2.0 , movie: Notes on a Scandal
# rating: 4.0 , movie: Cinderella Man
# {'Kiss of Death': 1.0, 'The Siege': 1.0, 'Death Sentence': 1.0, 'The Sentinel': 0.0, 'The Adventures of Ford Fairlane': 0.0, 'Kiss of the Dragon': 0.5, 'Transporter 2': 0.5, 'Taken 2': 0.5, 'Hitman': 1.5, 'All Superheroes Must Die': 0.0, 'Logans Run': 0.0, 'Enders Game': 0.0, 'The Lost Skeleton of Cadavra': 0.5, 'Terminator 3: Rise of the Machines': 0.0, 'Pacific Rim': 0.0, 'Splice': 0.0, 'Attack the Block': 0.0, 'Lockout': 0.0, 'The Fourth Kind': 0.0, 'Close Encounters of the Third Kind': 1.5, 'Halloween III: Season of the Witch': 0.5, 'Stake Land': 1.0, 'Kate & Leopold': 0.5, 'Man of Steel': 0.0, 'Star Wars': 0.0, 'Yesterday Was a Lie': 1.0, 'Mutant World': 0.5, 'CJ7': 1.5, 'The Astronaut Farmer': 1.5, 'Looper': 0.0, 'The I Inside': 0.0, 'The Giver': 1.5, 'Atlas Shrugged Part III: Who is John Galt?': 1.5, 'The Mist': 0.0, 'Congo': 1.0, 'Survival of the Dead': 0.5, 'Queen Crab': 0.5, 'Creative Control': 1.5, 'The Adjustment Bureau': 0.0, 'Face/Off': 0.0, 'Star Wars: Episode II - Attack of the Clones': 0.0, 'Nothing': 1.0, 'Automata': 0.0, 'K-PAX': 1.5, 'Invaders from Mars': 0.5, 'Megaforce': 0.0, 'Godzilla 2000': 0.0, 'Highlander: Endgame': 0.0, 'Hollow Man': 0.0, 'X2': 0.0, 'Stargate: The Ark of Truth': 0.5, 'Underworld: Evolution': 0.0, 'Escape from L.A.': 1.0, 'Bicentennial Man': 0.5, 'The Core': 0.0, 'Back to the Future Part II': 0.5, 'Warlock: The Armageddon': 0.5, 'Somewhere in Time': 1.5, 'Deep Blue Sea': 0.0, 'Guardians of the Galaxy': 0.0, 'Good Boy!': 0.5, 'Charly': 1.5, 'Beastmaster 2: Through the Portal of Time': 0.0, 'Delgo': 0.5, 'Star Trek Beyond': 0.0, 'Vessel': 0.5, 'The Adventures of Pluto Nash': 0.0, 'Conquest of the Planet of the Apes': 0.0, 'The Maze Runner': 0.0, 'Austin Powers in Goldmember': 0.5, 'The Saint': 0.0, 'Resident Evil: Afterlife': 0.0, 'The Fifth Element': 0.0, 'Project Almanac': 0.0, 'Idiocracy': 0.5, 'After Earth': 0.0, 'They Live': 0.0, 'The Andromeda Strain': 0.0, 'Home': 0.5, 'Apollo 18': 0.0, 'The Blood of Heroes': 0.0, 'Brazil': 0.5, 'Equilibrium': 0.0, 'The Inhabited Island': 0.0, 'E.T. the Extra-Terrestrial': 0.5, 'Tomorrowland': 0.5, 'Sleeper': 0.5, 'Armageddon': 0.0, 'Austin Powers: International Man of Mystery': 0.5, 'Species': 0.0, 'The Astronauts Wife': 1.0, 'Chain Reaction': 1.0, 'John Carter': 0.0, 'The Brain That Wouldnt Die': 0.5, 'Mad Max: Fury Road': 0.0, 'Star Trek VI: The Undiscovered Country': 0.0, 'Mirror Mirror': 1.5, 'Treasure Planet': 0.5, 'Aliens vs Predator: Requiem': 0.0, 'Space Battleship Yamato': 0.5, 'Under the Skin': 1.0, 'Escape from the Planet of the Apes': 0.0, 'Carriers': 1.0, 'Aliens': 0.0, 'Spawn': 0.0, 'Jekyll and Hyde ... Together Again': 0.5, 'Terminator Genisys': 0.0, 'The Shadow': 0.0, 'Contagion': 1.0, 'Earth to Echo': 0.5, 'Snowpiercer': 1.0, 'Atlas Shrugged Part II': 1.5, 'Detention': 0.5, 'Gravity': 1.0, 'Howard the Duck': 0.5, 'Star Wars: Episode III - Revenge of the Sith': 0.0, 'Resident Evil: Extinction': 0.0, 'Happily NEver After': 0.5, 'The Visitors': 0.5, 'G.I. Joe: Retaliation': 0.0, 'Underworld: Rise of the Lycans': 0.0, 'Code 46': 1.0, 'Battleship': 0.0, 'Iron Man 3': 0.0, 'Wild Wild West': 0.0, 'Interstellar': 1.5, 'The Lovers': 0.0, 'Decoys': 0.0, '28 Days Later': 0.0, 'Alien³': 0.0, 'Lost in Space': 0.5, 'Starship Troopers': 0.0, 'Monsters': 1.0, 'Star Trek III: The Search for Spock': 0.0, 'Transformers: Age of Extinction': 0.0, 'The Covenant': 0.0, 'District B13': 0.0, 'Independence Day': 0.0, 'Primer': 1.0, 'Renaissance': 0.0, 'Priest': 0.0, 'Firefox': 0.0, 'Listening': 1.0, 'Mad Max 2: The Road Warrior': 0.0, 'The Purge': 0.0, 'Red Planet': 0.0, 'Aliens in the Attic': 0.5, 'Dawn of the Planet of the Apes': 1.0, 'Akira': 0.5, 'AVP: Alien vs. Predator': 0.0, 'I Origins': 1.5, 'The Faculty': 0.5, 'Phantasm II': 0.0, 'Lucy': 0.0, 'Men in Black 3': 0.0, 'Transformers: Revenge of the Fallen': 0.0, 'Kingdom of the Spiders': 0.5, 'Avatar': 0.0, 'Captain America: The Winter Soldier': 0.0, 'The Flintstones in Viva Rock Vegas': 0.5, 'Sourc ...
# {'precision': 0.5316455696202531, 'recall': 0.5833333333333334, 'f1': 0.5562913907284769}
# 0it [00:00, ?it/s]
# rating: 3.5 , movie: Aliens vs Predator: Requiem
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 4.0 , movie: Dear Frankie
# rating: 4.0 , movie: Shine a Light
# rating: 3.5 , movie: Alvin and the Chipmunks
# rating: 2.5 , movie: Along Came Polly
# rating: 5.0 , movie: Space Jam
# rating: 2.5 , movie: Romeo + Juliet
# rating: 5.0 , movie: The Wedding Planner
# rating: 4.0 , movie: The Kite Runner
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 4.5 , movie: Match Point
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 4.0 , movie: Pandoras Box
# rating: 3.0 , movie: Wag the Dog
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating: 4.0 , movie: Cinderella Man
# rating: 4.5 , movie: Mission: Impossible
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 5.0 , movie: Solaris
# rating: 4.5 , movie: The Karate Kid
# rating: 3.0 , movie: Seven Samurai
# rating: 1.5 , movie: Mean Streets
# rating: 2.5 , movie: Maurice
# rating: 5.0 , movie: Madagascar
# rating: 2.0 , movie: About Schmidt
# rating: 1.0 , movie: Notting Hill
# rating: 5.0 , movie: Mission to Mars
# {'Alien Zone': -0.5, 'The League of Extraordinary Gentlemen': -0.5, 'Priest': -0.5, 'Ghost Rider': -0.5, 'They Live': -0.5, 'Daybreakers': -0.5, 'Carriers': 0.5, 'Aliens': -0.5, 'Spawn': 0.5, 'The Shadow': 0.5, 'The Darkest Hour': -0.5, 'Dragon Wars: D-War': 0.5, 'The Host': 0.5, 'Underworld: Evolution': -0.5, 'I Am Legend': 0.5, 'Phantasm II': -0.5, 'Race to Witch Mountain': 0.5, 'Stake Land': 0.5, 'Alone in the Dark': -0.5, 'The Inhabited Island': -0.5, 'Final Fantasy: The Spirits Within': 0.5, 'World War Z': 0.5, 'Underworld: Rise of the Lycans': 0.5, 'Pandorum': -0.5, 'Lifeforce': -0.5, 'Alien': -0.5, 'Split Second': -1.0, 'Anacondas: The Hunt for the Blood Orchid': -0.5, 'Dylan Dog: Dead of Night': -0.5, 'Twilight Zone: The Movie': 0.5, 'Dragonball Evolution': 0.5, 'The Devils Tomb': -0.5, 'Blade: Trinity': -0.5, 'Vampires': 0.5, 'Firestarter': 0.5, 'The Fifth Element': 0.5, 'Blade II': -0.5, 'eXistenZ': -0.5, 'The Covenant': 0.5, 'Lake Placid': -0.5, 'The Last Legion': 1.0, 'The Warriors Way': 0.5, 'Spider-Man 3': 0.5, 'The Hobbit: An Unexpected Journey': 0.5, 'In the Name of the King: A Dungeon Siege Tale': 1.5, 'Last Action Hero': 0.5, 'Night at the Museum': 0.5, 'Superman II': 0.5, 'Krull': 0.5, 'Mystery Men': 0.5, 'Thunderbirds': 0.5, 'BloodRayne': 0.5, 'Avatar': 0.5, 'Man of Steel': 0.5, 'The Last Airbender': 0.5, 'The Last Witch Hunter': 0.5, 'Superman III': 0.5, 'Teenage Mutant Ninja Turtles': 0.5, 'Maleficent': 0.5, 'Pirates of the Caribbean: At Worlds End': 0.5, '47 Ronin': 1.5, 'Batman': 0.0, 'Star Wars: Clone Wars: Volume 1': 0.5, 'In the Name of the King III': 1.5, 'Prince of Persia: The Sands of Time': 0.5, 'The Mortal Instruments: City of Bones': 1.5, 'Lara Croft: Tomb Raider': 0.5, 'Thor': 0.5, 'The Mummy: Tomb of the Dragon Emperor': 0.5, 'Eragon': 0.5, 'Lara Croft Tomb Raider: The Cradle of Life': 0.5, 'The Mummy Returns': 0.5, 'The Sorcerers Apprentice': 1.5, 'Monkeybone': 0.5, 'Highlander': 0.5, 'Spider-Man 2': 0.5, 'The Brothers Grimm': 0.5, 'Beastmaster 2: Through the Portal of Time': 0.5, 'The Amazing Spider-Man 2': 0.5, 'Night at the Museum: Battle of the Smithsonian': 0.5, 'Superman': 0.5, 'The Amazing Spider-Man': 0.5, 'Small Soldiers': 0.5, 'Conan the Barbarian': 0.5, 'The Scorpion King': 0.5, 'Jupiter Ascending': 0.5, 'The Lord of the Rings: The Two Towers': 0.5, 'Fantastic 4: Rise of the Silver Surfer': 0.5, 'Sheena': 0.5, 'Warcraft': 0.5, 'X-Men: Days of Future Past': 0.5, 'Teenage Mutant Ninja Turtles III': 0.5, 'Cirque du Freak: The Vampires Assistant': 0.5, 'Conan the Destroyer': 0.5, 'Pirates of the Caribbean: On Stranger Tides': 0.5, 'Superman Returns': 0.5, 'The Lord of the Rings: The Return of the King': 0.5, 'The 13th Warrior': 0.5, 'Reign of Fire': 0.5, 'Pirates of the Caribbean: Dead Mans Chest': 0.5, 'Brave': 1.5, 'The Lord of the Rings: The Fellowship of the Ring': 0.5, 'Jimmy Neutron: Boy Genius': 1.5, 'Clash of the Titans': 0.5, 'Dungeons & Dragons: Wrath of the Dragon God': 0.5, 'The Wolverine': 0.5, 'Red Sonja': 0.5, 'Suicide Squad': 0.0, 'Pirates of the Caribbean: The Curse of the Black Pearl': 0.5, 'Batman v Superman: Dawn of Justice': 0.5, 'Thor: The Dark World': 0.5, 'How to Train Your Dragon 2': 1.5, 'Teenage Mutant Ninja Turtles: Out of the Shadows': 0.5, 'The Hobbit: The Battle of the Five Armies': 0.5, 'Pokémon: Spell of the Unknown': 0.5, 'G-Force': 0.5, 'The Borrowers': 0.5, 'The Savages': 1.5, 'Alvin and the Chipmunks': 1.5, 'The Brave Little Toaster': 1, 'Shine a Light': 0, 'Wreck-It Ralph': 0, 'The Lego Movie': 1, 'A Monster in Paris': 1, 'The Croods': 1, 'Ratatouille': 1, 'Home': 1, 'This Is It': 0, 'Walk Hard: The Dewey Cox Story': 0, 'Shrek the Third': 1.5, 'Hotel Transylvania': 1, 'Shrek': 1, 'Shrek 2': 1, 'The Emperors New Groove': 1, 'Space Jam': 1.0, 'Alvin and the Chipmunks: Chipwrecked': 1, 'The Ant Bully': 1, 'Happily NEver After': 1, 'Aladdin': 1, 'Delgo': 1, 'Josie and the Pussycats': 0, 'Alvin and the Chipmunks: The Squeakquel': 1, 'The Book of Life': ...
# {'precision': 0.5189873417721519, 'recall': 0.5694444444444444, 'f1': 0.5430463576158941}
# 0it [00:00, ?it/s]
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# rating: 4.0 , movie: This Is 40
# rating: 3.5 , movie: Along Came a Spider
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 5.0 , movie: Madagascar
# rating: 0.5 , movie: Rebecca
# rating: 0.5 , movie: Amadeus
# rating: 4.0 , movie: Deconstructing Harry
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 4.5 , movie: The Island
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 1.5 , movie: The Butterfly Effect
# rating: 5.0 , movie: Mission to Mars
# rating: 4.0 , movie: The French Connection
# rating: 3.0 , movie: Psycho
# rating: 1.5 , movie: Mean Streets
# rating: 2.0 , movie: Moulin Rouge!
# rating: 1.0 , movie: Rocky Balboa
# rating: 4.0 , movie: Rambo III
# rating: 3.5 , movie: In Time
# rating: 1.0 , movie: Alexander
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 2.0 , movie: Dragonslayer
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 4.0 , movie: Shine a Light
# rating: 4.0 , movie: Horrible Bosses
# rating: 5.0 , movie: Dances with Wolves
# rating: 2.5 , movie: Along Came Polly
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 3.5 , movie: Star Trek: Generations
# {'8 Women': 0.0, 'In the Valley of Elah': 0.5, 'The Good German': 1.0, 'Confessions of a Dangerous Mind': 0.5, 'Legal Eagles': 1.0, 'Now You See Me 2': 0.0, 'The Adventures of Ford Fairlane': 0.5, 'All Good Things': 1.0, 'Zero Effect': 0.0, 'Disclosure': 1.0, 'Lucky Numbers': 0.5, 'Inherent Vice': 1.5, 'A Thin Line Between Love and Hate': 0.5, 'You Kill Me': 0.5, 'Moms Night Out': 1.5, 'xXx: State of the Union': 0.5, 'Harper': 0.5, 'The Limey': 0.5, 'Smillas Sense of Snow': 0.5, 'The Losers': -0.5, 'The Fugitive': -0.5, 'Copycat': 0.0, 'Basic': 0.5, 'The Net': 0.5, '10th & Wolf': 0.5, 'Nancy Drew': -0.5, 'The Corruptor': -0.5, 'Run All Night': 0.5, 'The Negotiator': 0.5, 'Alex Cross': -0.5, 'The Long Kiss Goodnight': -0.5, 'Young Sherlock Holmes': 0.5, 'Whiteout': -0.5, 'Sicario': 0.5, 'Shooter': 0.5, 'Match Point': 1.0, 'Summer of Sam': 1.0, 'Dear Wendy': 1.5, 'Bound': 1.0, 'Buffalo Soldiers': 1.0, 'Witness': 1.0, 'Mystic Pizza': 1.5, 'The Crying Game': 1.0, 'Duplicity': 1.0, 'Darling Lili': 1.0, 'Charlies Angels': 0.5, 'Buffalo 66': 1.5, 'The Curse of the Jade Scorpion': 0.5, 'Man of the Year': 1.0, 'The Mexican': 1.0, 'The Next Three Days': 1.0, 'Hes Just Not That Into You': 1.5, 'Death to Smoochy': 1.0, 'Lone Wolf McQuade': 1.0, 'Larry Crowne': 1.5, 'Alone With Her': 1.0, 'The Matador': 1.0, 'Clay Pigeons': 1.0, 'Focus': 1.5, 'Madagascar: Escape 2 Africa': 1, 'Heavenly Creatures': -0.5, 'Notes on a Scandal': -0.5, 'Conspiracy Theory': -1.0, 'The Postman Always Rings Twice': 0.0, 'Stir of Echoes': -1.5, 'Evita': -0.5, 'Cadillac Records': -0.5, '1776': 0.0, 'Joyeux Noël': -1.5, 'Tinker Tailor Soldier Spy': 0.0, 'G.I. Jane': 0.5, '2 Guns': 0.5, 'Riding in Cars with Boys': 1.0, 'Clear and Present Danger': 0.0, 'May': 0.0, 'Hoodwinked!': 1.0, 'Swingers': 1.0, 'The Vow': 0.5, 'Wild Grass': 0.5, 'Attack the Block': 0.5, 'Ratatouille': 1.0, 'Ask Me Anything': 0.0, 'Miss March': 1.0, 'Ray': 0.5, 'Boat Trip': 1.0, 'The Skeleton Key': 0.0, 'Moonrise Kingdom': 1.0, 'Dinner for Schmucks': 1.0, 'The Young Messiah': 0.5, 'Tanner Hall': 0.5, 'Zodiac': 0.5, 'Hot Tub Time Machine 2': 1.0, 'Miracle at St. Anna': 0.5, 'Safe Men': 0.5, 'Casino': 1.0, 'Fled': 0.5, 'The Work and the Glory II: American Zion': 0.5, 'The Woman in Black': 0.0, 'The Heat': 0.5, 'Limbo': 0.0, 'Hitman': 1.0, 'I Love You, Dont Touch Me!': 1.0, 'Smokin Aces': 0.0, 'Good Deeds': 1.0, 'Somewhere': 1.0, 'Yes Man': 1.0, '47 Ronin': 0.5, 'Detention of the Dead': 1.0, 'Shall We Dance?': 1.0, 'Congo': 0.5, 'Hits': 1.0, 'Superbad': 1.0, 'Nims Island': 1.0, 'A Woman, a Gun and a Noodle Shop': 0.5, 'Horrible Bosses 2': 1.0, 'Human Traffic': 1.0, 'Julia': 0.5, 'Dirty Work': 1.0, 'Eat Pray Love': 0.5, 'F.I.S.T.': 0.5, 'Perfume: The Story of a Murderer': 1.0, 'The Amazing Catfish': 1.0, 'Religulous': 1.0, 'The Amityville Horror': 0.0, 'The Widow of Saint-Pierre': 0.5, 'Nothing': 0.5, 'Misconduct': 0.0, 'K-PAX': 0.0, 'Blue Like Jazz': 1.0, 'Joe Somebody': 1.0, 'New in Town': 1.0, 'Chloe': 0.0, 'The Devils Rejects': 1.0, 'Bringing Down the House': 1.0, '21 Jump Street': 0.5, 'Johnny English': 1.0, 'Monkeybone': 1.0, 'Bicentennial Man': 0.5, 'Back to the Future Part II': 0.5, 'Boys Dont Cry': 1.0, 'Mozarts Sister': 0.5, 'Mother and Child': 0.5, 'Spotlight': 0.0, 'Fiddler on the Roof': 0.5, 'The Night Listener': 0.0, 'Love Stinks': 1.0, 'Harry Brown': 0.5, 'A Charlie Brown Christmas': 1.0, 'The Women': 1.0, 'This Christmas': 1.0, 'Minions': 1.0, 'Valley of the Wolves: Iraq': 0.5, 'Dr. Dolittle 2': 1.0, 'Zookeeper': 1.0, 'The Scarlet Letter': 0.5, 'The Untouchables': 0.5, 'Deuce Bigalow: European Gigolo': 1.0, 'Romeo Is Bleeding': 0.5, 'Disturbia': 0.0, 'Y Tu Mamá También': 0.5, 'Frailty': 0.5, 'Woman on Top': 1.0, 'The Tempest': 0.5, 'Oldboy': 0.0, 'Bubba Ho-tep': 0.5, 'Kung Fu Hustle': 0.5, 'Harold & Kumar Go to White Castle': 1.0, 'It Happened One Night': 1.0, 'Two Weeks Notice': 1.0, 'Coal Miners Daughter': 0.5, 'First Love, Last Rites': 0.5, 'Flight': 0.5, 'Lords of Dogtown': 0.5, 'S ...
# {'precision': 0.5340909090909091, 'recall': 0.6527777777777778, 'f1': 0.5874999999999999}
# 0it [00:00, ?it/s]
# rating: 5.0 , movie: Madagascar
# rating: 4.0 , movie: Barry Lyndon
# rating: 1.5 , movie: Mean Streets
# rating: 3.5 , movie: Alvin and the Chipmunks
# rating: 4.0 , movie: Interview with the Vampire
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 2.0 , movie: Moulin Rouge!
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 5.0 , movie: Dances with Wolves
# rating: 3.0 , movie: Kindergarten Cop
# rating: 1.0 , movie: 54
# rating: 4.5 , movie: Match Point
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 2.5 , movie: Romeo + Juliet
# rating: 4.0 , movie: Deconstructing Harry
# rating: 4.5 , movie: The Karate Kid
# rating: 4.0 , movie: Dear Frankie
# rating: 3.0 , movie: Lawrence of Arabia
# rating: 3.5 , movie: License to Wed
# rating: 2.0 , movie: Payback
# rating: 3.0 , movie: Seven Samurai
# rating: 2.5 , movie: Along Came Polly
# rating: 3.0 , movie: Spellbound
# rating: 0.5 , movie: Amadeus
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 4.0 , movie: The Transporter
# rating: 4.0 , movie: Cinderella Man
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 4.0 , movie: Shine a Light
# rating: 3.0 , movie: Wag the Dog
# {'Madagascar: Escape 2 Africa': 1, 'The Good German': 2.0, 'Alexander': 1.0, 'Tinker Tailor Soldier Spy': 0.5, 'G.I. Jane': 0.5, '2 Guns': 0.0, 'Riding in Cars with Boys': 0.5, 'Clear and Present Danger': 0.5, 'May': 0.5, 'The Vow': 0.5, 'Wild Grass': 0.5, 'Buffalo Soldiers': 1.0, 'Ask Me Anything': 0.5, 'Ray': 0.5, 'The Skeleton Key': 0.5, 'Moonrise Kingdom': 0.5, 'The Young Messiah': 0.5, 'Tanner Hall': 0.5, 'Miracle at St. Anna': 0.5, 'Safe Men': 0.0, 'Casino': 0.5, 'The Work and the Glory II: American Zion': 0.5, 'The Woman in Black': 0.5, 'The Heat': 0.0, 'Limbo': 0.5, 'Hitman': 1.0, 'Smokin Aces': 0.0, 'Good Deeds': 0.5, 'Somewhere': 0.5, '47 Ronin': 0.5, 'Shall We Dance?': 0.5, 'Congo': 0.5, 'Hits': 0.5, 'Pain & Gain': -0.5, 'A Woman, a Gun and a Noodle Shop': 0.5, 'Human Traffic': 0.5, 'Perfume: The Story of a Murderer': 0.5, 'Eat Pray Love': 0.5, 'F.I.S.T.': 0.5, 'Julia': 0.5, 'The Amityville Horror': 0.5, 'The Amazing Catfish': 0.5, 'The Widow of Saint-Pierre': 0.5, 'Misconduct': 0.5, 'Firestorm': -0.5, 'K-PAX': 0.5, 'Blue Like Jazz': 0.5, 'Chloe': 0.5, 'The Devils Rejects': 0.5, '21 Jump Street': 0.0, 'Boys Dont Cry': 0.5, 'Mozarts Sister': 0.5, 'Mother and Child': 0.5, 'Spotlight': 0.5, 'Fiddler on the Roof': 0.5, 'The Night Listener': 0.5, 'Harry Brown': 1.0, 'The Women': 0.5, 'This Christmas': 0.5, 'Zero Effect': 0.0, 'Valley of the Wolves: Iraq': 0.5, 'The Scarlet Letter': 0.5, 'Conspiracy Theory': 0.5, 'The Untouchables': 0.5, 'Y Tu Mamá También': 0.5, 'Romeo Is Bleeding': 0.5, 'Disturbia': 0.5, 'Frailty': 0.5, 'Woman on Top': 0.5, 'The Score': -0.5, 'The Tempest': 0.5, 'Oldboy': 0.5, 'Kung Fu Hustle': 0.0, 'Coal Miners Daughter': 0.5, 'First Love, Last Rites': 0.5, 'Panic Room': 0.5, 'Flight': 0.5, 'Lords of Dogtown': 0.5, 'Stealing Harvard': 0.5, 'Lords of London': -0.5, 'Hot Pursuit': 0.0, 'Witless Protection': 0.0, 'Seed of Chucky': 0.5, 'Futuro Beach': 0.5, 'Red Riding: In the Year of Our Lord 1974': 0.5, 'Foolish': 0.5, 'United Passions': 0.5, 'Body Double': -0.5, 'Gods and Generals': 0.5, 'U-571': 0.5, 'The Talented Mr. Ripley': 0.5, 'One for the Money': 0.0, 'Elizabethtown': 0.5, 'Never Back Down': 0.5, 'Stop-Loss': 0.5, 'Suspect Zero': -0.5, 'The Longest Ride': 0.5, 'A Passage to India': 0.5, 'Albert Nobbs': 0.5, 'Fort McCoy': 0.5, 'Insomnia': -0.5, 'Waterloo': 0.5, 'Flywheel': 0.5, 'Exodus: Gods and Kings': 0.5, 'Lovely & Amazing': 0.5, 'The Pursuit of D.B. Cooper': -0.5, 'Antarctica: A Year on Ice': 0.5, 'Romeo Must Die': -0.5, 'Mr. Hollands Opus': 0.5, 'Law Abiding Citizen': 0.5, 'Summer Catch': 0.5, 'Whale Rider': 0.5, 'My Dog Tulip': 0.5, 'The Town': 0.5, 'Moby Dick': 0.5, 'Hoot': 0.5, 'The Runaways': 0.5, 'Dreamer: Inspired By a True Story': 0.5, 'Caravans': 0.5, 'Airlift': 0.5, 'Fighting Tommy Riley': 0.5, 'The Firm': 0.5, 'Under the Skin': 0.5, 'The Celebration': 0.5, 'Idlewild': 0.5, 'The Wave': 0.5, 'The Art of Getting By': 0.5, 'Donnie Darko': 0.5, 'Dogtooth': 0.5, 'Simon Birch': 0.5, 'Light Sleeper': 0.5, 'Sparkle': 0.5, 'Carriers': 0.5, 'The Curious Case of Benjamin Button': 0.5, 'Brooklyns Finest': 0.5, 'Pierrot le Fou': 0.5, 'Forrest Gump': 0.5, 'Contagion': 0.5, 'When Did You Last See Your Father?': 0.5, 'Dolphin Tale': 0.5, 'Juliet and Alfa Romeo': 0.5, 'Kinsey': 0.5, 'Atlas Shrugged Part II': 0.5, 'Safe': -0.5, 'Gravity': 0.5, 'The Libertine': 0.5, 'The Fault in Our Stars': 0.5, 'The Bad Lieutenant: Port of Call - New Orleans': 0.5, 'The Terminal': 0.5, 'The Art of War': -0.5, 'The Horse Whisperer': 0.5, 'The Taking of Pelham 1 2 3': 0.5, 'Angelas Ashes': 0.5, 'Hud': 0.5, 'Taxman': 0.0, 'Finding Forrester': 0.5, 'Doubt': 0.5, 'Cruel Intentions': 0.5, 'The Hustler': 0.5, 'I Married a Strange Person!': 0.5, 'Exotica': 0.5, 'Judgment at Nuremberg': 0.5, 'Brick Lane': 0.5, 'The Second Best Exotic Marigold Hotel': 0.5, 'Primer': 0.5, 'Eraser': 0.5, 'Max': 0.5, 'The Lovely Bones': 0.5, 'Joe': 0.5, 'Magic Mike XXL': 0.5, 'The Pet': 0.5, 'Malevolence': -0.5, 'I Love Your Work': 0.5, 'Mr. Turn ...
# {'precision': 0.5567010309278351, 'recall': 0.75, 'f1': 0.6390532544378699}
# 0it [00:00, ?it/s]
# rating: 2.0 , movie: Payback
# rating: 2.0 , movie: Moulin Rouge!
# rating: 5.0 , movie: Space Jam
# rating: 4.0 , movie: Shine a Light
# rating: 4.0 , movie: Interview with the Vampire
# rating: 3.0 , movie: Friends with Money
# rating: 1.0 , movie: Alexander
# rating: 4.0 , movie: Deconstructing Harry
# rating: 5.0 , movie: Mission to Mars
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 4.0 , movie: The French Connection
# rating: 4.0 , movie: Flash Gordon
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 3.0 , movie: Lawrence of Arabia
# rating: 4.5 , movie: U-571
# rating: 2.0 , movie: The Sixth Sense
# rating: 4.0 , movie: The Kite Runner
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 0.5 , movie: Rebecca
# rating: 3.0 , movie: Gothika
# rating: 3.5 , movie: License to Wed
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 3.5 , movie: Star Trek: Generations
# rating: 2.0 , movie: The Last Emperor
# rating: 5.0 , movie: Amélie
# rating: 4.0 , movie: Rambo III
# rating: 2.0 , movie: Being John Malkovich
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# {'Kiss of Death': 2.0, 'Takers': 1.5, 'Need for Speed': 1.5, 'The Devils Double': 2.0, 'Stolen': 1.5, 'Mercury Rising': 1.5, 'The Protector': 1.5, 'Patriot Games': 1.5, 'The Yards': 1.5, 'Faster': 1.5, 'The Baader Meinhof Complex': 1.5, 'The Way of the Gun': 1.5, 'xXx: State of the Union': 1.5, 'Harper': 1.5, 'Dark Blue': 1.5, 'Jimmy and Judy': 1.5, 'Drive': 1.5, 'Prisoners': 1.5, 'Smillas Sense of Snow': 1.5, 'The Limey': 1.5, 'Vantage Point': 1.5, 'The Death and Life of Bobby Z': 1.5, 'Death Sentence': 2.0, 'Harsh Times': 1.5, 'Point Blank': 1.5, 'Killing Zoe': 1.5, 'Street Kings': 1.5, 'Machine Gun McCain': 1.5, 'Dead Man Down': 1.5, 'Contraband': 1.5, 'The Proposition': 1.5, 'Righteous Kill': 1.5, 'In Too Deep': 1.5, 'Training Day': 1.5, 'Running Scared': 1.5, 'I Am Wrath': 1.5, 'Basic': 1.5, 'Rampage': 1.5, 'Harry Brown': 1.5, 'Double Impact': 1.5, '10th & Wolf': 1.5, 'Man on Fire': 1.5, 'The Net': 1.5, 'United 93': 1.5, 'The Fast and the Furious: Tokyo Drift': 1.5, 'Hackers': 1.5, 'The Siege': 2.0, 'The Hunted': 1.5, 'Run All Night': 1.5, '3 Days to Kill': 1.5, 'Gangster Squad': 1.5, 'Narc': 1.5, 'The Negotiator': 1.5, 'Sabotage': 1.5, 'The Dark Knight': 1.5, 'Bound by Honor': 1.5, 'A History of Violence': 1.5, 'Hitman': 2.0, 'Shinjuku Incident': 1.5, 'Armored': 1.5, 'Scarface': 1.5, 'Young Sherlock Holmes': 1.5, 'Romeo Is Bleeding': 1.5, 'Colombiana': 1.5, 'The Replacement Killers': 1.5, 'Lone Wolf McQuade': 2.5, 'Class of 1984': 1.5, 'Get Carter': 1.5, 'The Glimmer Man': 1.5, 'Sicario': 1.5, 'The Matador': 2.5, 'The Dark Knight Rises': 1.5, 'Shooter': 1.5, 'The Sound of Music': 2.5, 'The Rose': 2.5, 'Love Me Tender': 2.5, 'Alexanders Ragtime Band': 2.5, 'The Brave Little Toaster': 2.5, 'The Lego Movie': 2.5, 'The Odd Life of Timothy Green': 3.5, 'A Monster in Paris': 2.5, 'The Croods': 2.5, 'Ratatouille': 2.5, 'Like Mike': 3.5, 'Home': 3.0, 'Shrek the Third': 3.0, 'Babe: Pig in the City': 3.5, 'Hotel Transylvania': 2.5, 'Shrek': 2.5, 'Shrek 2': 2.5, 'The Emperors New Groove': 2.5, 'The Muppet Christmas Carol': 3.5, 'Alvin and the Chipmunks: Chipwrecked': 2.5, 'The Ant Bully': 2.5, 'Just My Luck': 3.5, 'Monster House': 2.5, 'Happily NEver After': 3.0, 'Arthur Christmas': 3.5, 'Aladdin': 2.5, 'Delgo': 3.0, 'CJ7': 4.0, 'Alvin and the Chipmunks: The Squeakquel': 2.5, 'The Book of Life': 2.5, 'Quest for Camelot': 3.5, 'Ernest & Celestine': 3.5, 'The Smurfs 2': 2.5, 'How to Train Your Dragon 2': 2.5, 'Jonah: A VeggieTales Movie': 2.5, 'Inside Out': 3.5, 'Stuart Little': 2.5, 'The Smurfs': 2.5, 'Babe': 3.5, 'The Santa Clause': 3.5, 'Shrek Forever After': 2.5, 'The Boxtrolls': 2.5, 'Alvin and the Chipmunks': 3.0, 'Mirror Mirror': 4.0, 'Big': 3.5, 'Brave': 2.5, 'Jimmy Neutron: Boy Genius': 3.5, 'The Little Vampire': 0.5, 'Dracula 2000': 0.5, 'Dracula Untold': 2.0, 'Queen of the Damned': 2.0, 'The Twilight Saga: Eclipse': 3.0, 'Hes Just Not That Into You': 2.5, 'The Switch': 2.5, 'Saints and Soldiers': 0.5, 'Solomon and Sheba': 1.5, 'In the Heart of the Sea': 1.0, '13 Hours: The Secret Soldiers of Benghazi': 1.0, 'Proof of Life': 2.0, 'Tora! Tora! Tora!': 0.5, 'Top Gun': 1.0, 'A Knights Tale': 2.0, 'Windtalkers': 0.5, 'Braveheart': 0.5, 'Double Take': 2.0, 'The Horseman on the Roof': 2.0, 'Joyeux Noël': 1.5, 'Baahubali: The Beginning': 0.0, 'The Last Samurai': 0.5, 'Robin and Marian': 2.0, 'Sands of Iwo Jima': 0.5, 'The Host': 2.5, 'The Great Escape': 0.5, 'Kingdom of Heaven': 0.5, 'Legends of the Fall': 2.0, 'The Longest Day': 0.5, 'The Four Feathers': 2.0, 'House of Flying Daggers': 2.0, 'Das Boot': 0.5, 'Ironclad': 1.0, 'The Patriot': 0.5, 'Crouching Tiger, Hidden Dragon': 2.0, 'First Knight': 2.0, 'Green Zone': 2.0, 'Lions for Lambs': 1.0, 'March or Die': 1.0, 'Quigley Down Under': 2.0, 'Passchendaele': 1.5, 'The Charge of the Light Brigade': 1.0, 'Tombstone': 1.0, 'Henry V': 1.5, 'Arn: The Knight Templar': 2.0, 'Red Tails': 0.5, 'Free State of Jones': 1.0, 'Highway': 1.0, 'Beyond Borders': 2.0, 'Letters from Iwo Jima': 1.0, ...
# {'precision': 0.5454545454545454, 'recall': 0.8333333333333334, 'f1': 0.6593406593406592}
